# %% [markdown]
# ### This project features interactive maps and HTML markup. Since Github does not support dynamic displays for notebooks, it is necessary to download the project to render the elements and to manipulate the data visualizations.
#
# # Data Analysis
#
# This is the <b>second in a series of three Jupyter notebooks</b> on the 2018 Food Consumption and CO<sub>2</sub> Emissions. This activity is in partial fulfillment of the Tidy Tuesdays deliverables for probationary Lyrids of the <b>Center for Complexity and Emerging Technologies, College of Computer Studies, De La Salle University</b>.
#
# <b>Climate change and global warming are pressing environmental issues &mdash; and among the foremost drivers of these are human-induced emissions of greenhouse gases, such as carbon dioxide (CO<sub>2</sub>)</b>. While this project does not seek to present a professional or rigorous statistical analysis, the author of this series of Jupyter notebooks would like to increase awareness on the importance of data-driven policy directions and to hopefully contribute to the present discourse on how food consumption can greatly impact our carbon footprint.
#
# <hr/>
#
# The required dataset for this Tidy Tuesdays activity is the 2018 Food Consumption and CO<sub>2</sub> Emissions from the R Community's Tidy Tuesdays (Github): https://github.com/rfordatascience/tidytuesday/tree/master/data/2020/2020-02-18.
#
# To enrich the analysis and visualization, the following datasets were integrated:
#
# - Country Codes and Names - http://country.io/names.json
# - World Bank Country and Lending Groups (Classification for the 2018 Fiscal Year) - https://datahelpdesk.worldbank.org/knowledgebase/articles/906519-world-bank-country-and-lending-groups
#
# These datasets are stored in the folder <code>data</code> of the repository.

# %% [markdown]
# # PRELIMINARIES *(Lifted from Data Preparation)*

# %% [markdown]
# <b>Due to restrictions related to the size of files in Github repositories, the project had to be divided into separate notebooks. In this regard, this section is just a repeat of pertinent code excerpts from the data preparation phase. </b>
#
# For the complete documentation, please refer to this notebook: <code>1. Data Preparation.ipynb</code>.

# %%
import re
import json

import pandas as pd
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
from pywaffle import Waffle

import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from plotly.offline import iplot, init_notebook_mode
init_notebook_mode(connected = True)

pd.options.mode.chained_assignment = None  

NUM_ROWS = 10

pd.set_option('display.max_rows', NUM_ROWS)
pd.set_option('display.min_rows', NUM_ROWS)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
standardized_names = [("Taiwan. ROC", "Taiwan"),
                      ("USA", "United States"),
                      ("Hong Kong SAR. China", "Hong Kong"),
                      ("Congo", "Republic of the Congo")]

standardized_categories = [("Milk - inc. cheese", "Milk & Cheese"),
                           ("Wheat and Wheat Products", "Wheat & Wheat Products"),
                           ("Nuts inc. Peanut Butter", "Nuts & Peanut Butter")]

# %%
data_raw = pd.read_csv('data/food_consumption.csv')
data = data_raw.copy(deep = True)

for name in standardized_names:
    data['country'] = data['country'].str.replace(re.escape(name[0]), name[1])
    
for category in standardized_categories:
    data['food_category'] = data['food_category'].str.replace(re.escape(category[0]), category[1])

# %% [markdown]
# <hr/>

# %% [markdown]
# # DATA ANALYSIS

# %% [markdown]
# Essentially, the dataset presents country-level data on the consumption (in kg/person/year) of categories of food products and the associated carbon dioxide emission (in kg CO<sub>2</sub>/person/year). This nature of the dataset, thus, lends itself to three themes of analysis:
# - Consumption and emission by country
# - Consumption and emission by food product
# - Correlations between selected variables
#
# The goal of this step is twofold: (1) detecting anomalies that may have to be addressed before proceeding to visualization and further analysis (or, possibly, forecasting) and (2) recognizing notable trends and patterns that may hopefully enrich our understanding of the data at hand.

# %% [markdown]
# ### *Animal-Based vs. Plant-Based Products*

# %% [markdown]
# An interesting angle to explore, as suggested by its creator (nu3, 2018), is splitting the food categories into those that are animal-based and plant-based.

# %%
animal_products = ['country', 'Beef', 'Eggs', 'Fish', 'Lamb & Goat', 'Milk & Cheese', 'Pork', 'Poultry']
plant_products = ['country', 'Nuts & Peanut Butter', 'Rice', 'Soybeans', 'Wheat & Wheat Products']

# %% [markdown]
# *The under-the-hood implementation of having the first entry of each list as <code>country</code>* is in light of the structure of the pivot dataset (which will be constructed in the next section).

# %% [markdown]
# ## A. By Country

# %% [markdown]
# We first perform an independent (separate) analysis of the country-level data related to consumption and carbon dioxide emission.

# %% [markdown]
# ### 1. Consumption

# %% [markdown]
# We pivot the dataset so that the columns are now the food categories and each row corresponds to a country. We also add a column showing the total consumption per country.

# %%
country_data = data.pivot(index = 'country', columns = 'food_category', values = 'consumption').reset_index()

country_data['TOTAL'] = country_data['Beef'] + country_data['Eggs'] + country_data['Fish'] \
                        + country_data['Lamb & Goat'] + country_data['Milk & Cheese'] \
                        + country_data['Nuts & Peanut Butter'] + country_data['Pork'] + country_data['Poultry'] \
                        + country_data['Rice'] + country_data['Soybeans'] + country_data['Wheat & Wheat Products']

print("-- Food Product Consumption per Country --")
country_data
# Out:
# -- Food Product Consumption per Country --
# food_category    country   Beef   Eggs   Fish  Lamb & Goat  Milk & Cheese  \
# 0                Albania  22.50  12.45   3.85        15.32         303.72
# 1                Algeria   5.60   8.06   3.74         7.69         141.53
# 2                 Angola   8.42   1.11  15.24         1.08          12.30
# 3              Argentina  55.48  11.39   4.36         1.56         195.08
# 4                Armenia  19.66  11.69   4.36         3.02         209.03
# ..                   ...    ...    ...    ...          ...            ...
# 125              Uruguay  29.10  13.14   6.53         8.23         210.54
# 126            Venezuela  25.89   5.63   8.34         0.32         117.79
# 127              Vietnam   7.44   3.84  26.52         0.14          16.36
# 128               Zambia   4.76   3.32   6.20         0.68           9.71
# 129             Zimbabwe   7.37   1.75   2.80         0.96          31.90
#
# food_category  Nuts & Peanut Butter   Pork  Poultry    Rice  Soybeans  \
# 0                              4.36  10.88    13.23    7.78      0.00
# 1                              2.08   0.00     7.42    2.97      0.00
# 2                              2.26   8.89    17.33    8.12      0.52
# 3                              0.49  10.51    38.66    8.77      0.00
# 4                              2.55   9.67    13.35    3.18      0.00
# ..                              ...    ...      ...     ...       ...
# 125                            0.95  16.84    27.45   11.50      0.01
# 126                            0.35   7.23    39.28   23.39      0.00
# 127                            6.28  35.00    12.36  144.56      5.75
# 128                            5.04   1.66     3.29    3.05      7.30
# 129                            2.22   2.65     4.97   10.09      0.54
#
# food_category  Wheat & Wheat Products   TOTAL
# 0                              138.64  532.73
# 1                              185.42  364.51
# 2                               40.72  115.99
# 3                              103.11  429.41
# 4                              130.60  407.11
# ..                                ...     ...
# 125                            109.31  433.60
# 126                             49.17  277.39
# 127                             10.49  268.74
# 128                             12.10   57.11
# 129                             31.31   96.56
#
# [130 rows x 13 columns]

# %% [markdown]
# We arrange the entries based on the total consumption. As a preliminary visualization, we employ blue gradients to correspond to the amount of food products consumed.

# %%
sorted_country_data = country_data.sort_values(by = 'TOTAL', ascending = False).reset_index(drop = True)

print("-- Food Product Consumption per Country (Sorted) --")
sorted_country_data.style.background_gradient(cmap = 'Blues')
# Out:
# -- Food Product Consumption per Country (Sorted) --
# <style  type="text/css" >
#     #T_e427e062_a763_11eb_b623_a81e840b27ffrow0_col1 {
#             background-color:  #aacfe5;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow0_col2 {
#             background-color:  #6dafd7;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow0_col3 {
#             background-color:  #d3e3f3;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow0_col4 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow0_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow0_col6 {
#             background-color:  #dbe9f6;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow0_col7 {
#             background-color:  #5fa6d1;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow0_col8 {
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow0_col9 {
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow0_col10 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow0_col11 {
#             background-color:  #91c3de;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow0_col12 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow1_col1 {
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow1_col2 {
#             background-color:  #3383be;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow1_col3 {
#             background-color:  #c9ddf0;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow1_col4 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow1_col5 {
#             background-color:  #3282be;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow1_col6 {
#             background-color:  #e7f0fa;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow1_col7 {
#             background-color:  #3383be;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow1_col8 {
#             background-color:  #8abfdd;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow1_col9 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow1_col10 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow1_col11 {
#             background-color:  #4695c8;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow1_col12 {
#             background-color:  #0b559f;
#             color:  #f1f1f1;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow2_col1 {
#             background-color:  #85bcdc;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow2_col2 {
#             background-color:  #2f7fbc;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow2_col3 {
#             background-color:  #ddeaf7;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow2_col4 {
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow2_col5 {
#             background-color:  #1966ad;
#             color:  #f1f1f1;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow2_col6 {
#             background-color:  #c2d9ee;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow2_col7 {
#             background-color:  #5aa2cf;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow2_col8 {
#             background-color:  #c3daee;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow2_col9 {
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow2_col10 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow2_col11 {
#             background-color:  #95c5df;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow2_col12 {
#             background-color:  #0d57a1;
#             color:  #f1f1f1;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow3_col1 {
#             background-color:  #b3d3e8;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow3_col2 {
#             background-color:  #2676b8;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow3_col3 {
#             background-color:  #e3eef8;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow3_col4 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow3_col5 {
#             background-color:  #1966ad;
#             color:  #f1f1f1;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow3_col6 {
#             background-color:  #aacfe5;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow3_col7 {
#             background-color:  #5da5d1;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow3_col8 {
#             background-color:  #9dcae1;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow3_col9 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow3_col10 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow3_col11 {
#             background-color:  #a8cee4;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow3_col12 {
#             background-color:  #125ea6;
#             color:  #f1f1f1;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow4_col1 {
#             background-color:  #95c5df;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow4_col2 {
#             background-color:  #3c8cc3;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow4_col3 {
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow4_col4 {
#             background-color:  #2777b8;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow4_col5 {
#             background-color:  #2e7ebc;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow4_col6 {
#             background-color:  #d3e4f3;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow4_col7 {
#             background-color:  #d7e6f5;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow4_col8 {
#             background-color:  #cfe1f2;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow4_col9 {
#             background-color:  #eff6fc;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow4_col10 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow4_col11 {
#             background-color:  #2f7fbc;
#             color:  #000000;
#         }    #T_e427e062_a763_11eb_b623_a81e840b27ffrow4_col12 {
#             background-color:  #125ea6;
#             color

# %% [markdown]
# Below are some observations that can be noted from the table above:
# - The ten countries with the highest record of food product consumption are all in Europe, with Finland being the top consumer (639.79 kg/person/year). In particular, there is a noticeably high consumption of milk and cheese, eggs, and pork. It is to be noted that the European Union is the biggest cheese and skin milk powder exporter globally, as well as the second-largest producer and the foremost exporter of pork in the world (European Union, 2021).
# - In these countries, the consumption of milk and cheese products also far outweighs those of others, contributing to over half of their total consumption.
# - On the other hand, the ten countries with the lowest record of food product consumption are all in Africa, with Rwanda being the lowest consumer (40 kg/person/year).
# - This trend may possibly indicate a relationship between the economy of a country and consumption. Consumption is intrinsically tied with the available resources of a country. In particular, countries with enough or above-adequate resources for the production and even participate in the trade of goods also tend to have a more ample supply of food products (either locally produced or imported) for the consumption of their citizens.

# %% [markdown]
# ### *Animal-Based Food Products*

# %% [markdown]
# We now zero in on the food products that are derived from animals.

# %%
animal_country_data = country_data[animal_products]

animal_country_data['TOTAL'] = animal_country_data['Beef'] + animal_country_data['Eggs'] + animal_country_data['Fish'] \
                               + animal_country_data['Lamb & Goat'] + animal_country_data['Milk & Cheese'] \
                               + animal_country_data['Pork'] + animal_country_data['Poultry']

print("-- Animal-Based Food Product Consumption per Country --")
animal_country_data
# Out:
# -- Animal-Based Food Product Consumption per Country --
# food_category    country   Beef   Eggs   Fish  Lamb & Goat  Milk & Cheese  \
# 0                Albania  22.50  12.45   3.85        15.32         303.72
# 1                Algeria   5.60   8.06   3.74         7.69         141.53
# 2                 Angola   8.42   1.11  15.24         1.08          12.30
# 3              Argentina  55.48  11.39   4.36         1.56         195.08
# 4                Armenia  19.66  11.69   4.36         3.02         209.03
# ..                   ...    ...    ...    ...          ...            ...
# 125              Uruguay  29.10  13.14   6.53         8.23         210.54
# 126            Venezuela  25.89   5.63   8.34         0.32         117.79
# 127              Vietnam   7.44   3.84  26.52         0.14          16.36
# 128               Zambia   4.76   3.32   6.20         0.68           9.71
# 129             Zimbabwe   7.37   1.75   2.80         0.96          31.90
#
# food_category   Pork  Poultry   TOTAL
# 0              10.88    13.23  381.95
# 1               0.00     7.42  174.04
# 2               8.89    17.33   64.37
# 3              10.51    38.66  317.04
# 4               9.67    13.35  270.78
# ..               ...      ...     ...
# 125            16.84    27.45  311.83
# 126             7.23    39.28  204.48
# 127            35.00    12.36  101.66
# 128             1.66     3.29   29.62
# 129             2.65     4.97   52.40
#
# [130 rows x 9 columns]

# %% [markdown]
# We arrange the entries based on the total consumption. As a preliminary visualization, we employ red gradients to correspond to the amount of food products consumed.

# %%
sorted_animal_country_data = animal_country_data.sort_values(by = 'TOTAL', ascending = False).reset_index(drop = True)

print("-- Animal-Based Food Product Consumption per Country (Sorted) --")
sorted_animal_country_data.style.background_gradient(cmap = 'Reds')
# Out:
# -- Animal-Based Food Product Consumption per Country (Sorted) --
# <style  type="text/css" >
#     #T_e4935158_a763_11eb_9c05_a81e840b27ffrow0_col1 {
#             background-color:  #fc9e80;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow0_col2 {
#             background-color:  #fb6c4c;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow0_col3 {
#             background-color:  #fdcebb;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow0_col4 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow0_col5 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow0_col6 {
#             background-color:  #f75c41;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow0_col7 {
#             background-color:  #fca689;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow0_col8 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow1_col1 {
#             background-color:  #fc7f5f;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow1_col2 {
#             background-color:  #da2723;
#             color:  #f1f1f1;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow1_col3 {
#             background-color:  #fedfd0;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow1_col4 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow1_col5 {
#             background-color:  #be151a;
#             color:  #f1f1f1;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow1_col6 {
#             background-color:  #f6563d;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow1_col7 {
#             background-color:  #fcb89e;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow1_col8 {
#             background-color:  #b31218;
#             color:  #f1f1f1;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow2_col1 {
#             background-color:  #fca78b;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow2_col2 {
#             background-color:  #d11e1f;
#             color:  #f1f1f1;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow2_col3 {
#             background-color:  #fee4d8;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow2_col4 {
#             background-color:  #ffeee6;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow2_col5 {
#             background-color:  #be151a;
#             color:  #f1f1f1;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow2_col6 {
#             background-color:  #f75b40;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow2_col7 {
#             background-color:  #fc9272;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow2_col8 {
#             background-color:  #b61319;
#             color:  #f1f1f1;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow3_col1 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow3_col2 {
#             background-color:  #de2b25;
#             color:  #f1f1f1;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow3_col3 {
#             background-color:  #fcbfa7;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow3_col4 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow3_col5 {
#             background-color:  #dd2a25;
#             color:  #f1f1f1;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow3_col6 {
#             background-color:  #de2b25;
#             color:  #f1f1f1;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow3_col7 {
#             background-color:  #fc8262;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow3_col8 {
#             background-color:  #c4161c;
#             color:  #f1f1f1;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow4_col1 {
#             background-color:  #fc9373;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow4_col2 {
#             background-color:  #f7593f;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow4_col3 {
#             background-color:  #fee9df;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow4_col4 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow4_col5 {
#             background-color:  #cf1c1f;
#             color:  #f1f1f1;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow4_col6 {
#             background-color:  #fb7353;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow4_col7 {
#             background-color:  #fcb99f;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow4_col8 {
#             background-color:  #cc191e;
#             color:  #f1f1f1;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow5_col1 {
#             background-color:  #fc8d6d;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow5_col2 {
#             background-color:  #fb7656;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow5_col3 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow5_col4 {
#             background-color:  #fdccb8;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow5_col5 {
#             background-color:  #e12d26;
#             color:  #f1f1f1;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow5_col6 {
#             background-color:  #fb7050;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow5_col7 {
#             background-color:  #fc8565;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow5_col8 {
#             background-color:  #d21f20;
#             color:  #f1f1f1;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow6_col1 {
#             background-color:  #e93529;
#             color:  #f1f1f1;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow6_col2 {
#             background-color:  #c8171c;
#             color:  #f1f1f1;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow6_col3 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow6_col4 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow6_col5 {
#             background-color:  #f34935;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow6_col6 {
#             background-color:  #fc8666;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow6_col7 {
#             background-color:  #bc141a;
#             color:  #f1f1f1;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow6_col8 {
#             background-color:  #d72322;
#             color:  #f1f1f1;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow7_col1 {
#             background-color:  #fcc2aa;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow7_col2 {
#             background-color:  #fc8262;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow7_col3 {
#             background-color:  #fc8666;
#             color:  #000000;
#         }    #T_e4935158_a763_11eb_9c05_a81e840b27ffrow7_col4 {
#             background-color:  #67000d;
#             color:  #f1f1f1;

# %% [markdown]
# Below are some observations that can be noted from the table above:
#
# - Once again, the ten countries with the highest record of consumption are mostly from Europe, with the sole exception of the United States. Finland, which is the overall top consumer at 549.87 kg/person/year, is also the top consumer of milk and cheese products in the world, at 430.75 kg/person/year. Meanwhile, Iceland (which is ranked 8<sup>th</sup>, consuming 391.51 kg/person/year) is the top consumer of lamb and goat products globally (21.12 kg/person/year).
# - In these countries, the consumption of milk and cheese products also far outweighs those of others. Considering only animal-based food consumption, over three-fourths (> 75%) can be attributed to milk and cheese products alone.
# - Similar to the trend observed with respect to the overall food consumption, the ten countries with the lowest record of animal-based food product consumption are all in Africa, with Rwanda still being the lowest consumer at 17.83 kg/person/year.
# - This trend may possibly indicate a relationship between the economy of a country and consumption. Consumption is intrinsically tied with the available resources of a country. In particular, countries with enough or above-adequate resources for the production and even participate in the trade of goods also tend to have a more ample supply of food products (either locally produced or imported) for the consumption of their citizens.

# %% [markdown]
# ### *Plant-Based Food Products*

# %% [markdown]
# We now zero in on the food products that are derived from plants.

# %%
plant_country_data = country_data[plant_products]

plant_country_data['TOTAL'] = plant_country_data['Nuts & Peanut Butter'] \
                              + plant_country_data['Rice'] + plant_country_data['Soybeans'] \
                              + plant_country_data['Wheat & Wheat Products']

print("-- Plant-Based Food Product Consumption per Country --")
plant_country_data
# Out:
# -- Plant-Based Food Product Consumption per Country --
# food_category    country  Nuts & Peanut Butter    Rice  Soybeans  \
# 0                Albania                  4.36    7.78      0.00
# 1                Algeria                  2.08    2.97      0.00
# 2                 Angola                  2.26    8.12      0.52
# 3              Argentina                  0.49    8.77      0.00
# 4                Armenia                  2.55    3.18      0.00
# ..                   ...                   ...     ...       ...
# 125              Uruguay                  0.95   11.50      0.01
# 126            Venezuela                  0.35   23.39      0.00
# 127              Vietnam                  6.28  144.56      5.75
# 128               Zambia                  5.04    3.05      7.30
# 129             Zimbabwe                  2.22   10.09      0.54
#
# food_category  Wheat & Wheat Products   TOTAL
# 0                              138.64  150.78
# 1                              185.42  190.47
# 2                               40.72   51.62
# 3                              103.11  112.37
# 4                              130.60  136.33
# ..                                ...     ...
# 125                            109.31  121.77
# 126                             49.17   72.91
# 127                             10.49  167.08
# 128                             12.10   27.49
# 129                             31.31   44.16
#
# [130 rows x 6 columns]

# %% [markdown]
# We arrange the entries based on the total consumption. As a preliminary visualization, we employ green gradients to correspond to the amount of food products consumed.

# %%
sorted_plant_country_data = plant_country_data.sort_values(by = 'TOTAL', ascending = False).reset_index(drop = True)

print("-- Plant-Based Food Product Consumption per Country  (Sorted) --")
sorted_plant_country_data.style.background_gradient(cmap = 'Greens')
# Out:
# -- Plant-Based Food Product Consumption per Country  (Sorted) --
# <style  type="text/css" >
#     #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow0_col1 {
#             background-color:  #c1e6ba;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow0_col2 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow0_col3 {
#             background-color:  #e7f6e3;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow0_col4 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow0_col5 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow1_col1 {
#             background-color:  #6abf71;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow1_col2 {
#             background-color:  #dbf1d5;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow1_col3 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow1_col4 {
#             background-color:  #1d8640;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow1_col5 {
#             background-color:  #005723;
#             color:  #f1f1f1;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow2_col1 {
#             background-color:  #f4fbf1;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow2_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow2_col3 {
#             background-color:  #f2faef;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow2_col4 {
#             background-color:  #ecf8e8;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow2_col5 {
#             background-color:  #006027;
#             color:  #f1f1f1;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow3_col1 {
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow3_col2 {
#             background-color:  #f5fbf3;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow3_col3 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow3_col4 {
#             background-color:  #005723;
#             color:  #f1f1f1;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow3_col5 {
#             background-color:  #006027;
#             color:  #f1f1f1;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow4_col1 {
#             background-color:  #abdda5;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow4_col2 {
#             background-color:  #eff9ec;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow4_col3 {
#             background-color:  #e9f7e5;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow4_col4 {
#             background-color:  #05712f;
#             color:  #f1f1f1;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow4_col5 {
#             background-color:  #006027;
#             color:  #f1f1f1;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow5_col1 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow5_col2 {
#             background-color:  #ccebc6;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow5_col3 {
#             background-color:  #f2faef;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow5_col4 {
#             background-color:  #258d47;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow5_col5 {
#             background-color:  #006328;
#             color:  #f1f1f1;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow6_col1 {
#             background-color:  #e3f4de;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow6_col2 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow6_col3 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow6_col4 {
#             background-color:  #006227;
#             color:  #f1f1f1;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow6_col5 {
#             background-color:  #006b2b;
#             color:  #f1f1f1;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow7_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow7_col2 {
#             background-color:  #b1e0ab;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow7_col3 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow7_col4 {
#             background-color:  #72c375;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow7_col5 {
#             background-color:  #03702e;
#             color:  #f1f1f1;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow8_col1 {
#             background-color:  #e9f7e5;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow8_col2 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow8_col3 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow8_col4 {
#             background-color:  #0d7836;
#             color:  #f1f1f1;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow8_col5 {
#             background-color:  #16803c;
#             color:  #f1f1f1;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow9_col1 {
#             background-color:  #f1faee;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow9_col2 {
#             background-color:  #005b25;
#             color:  #f1f1f1;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow9_col3 {
#             background-color:  #c6e8bf;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow9_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow9_col5 {
#             background-color:  #17813d;
#             color:  #f1f1f1;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow10_col1 {
#             background-color:  #c2e7bb;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow10_col2 {
#             background-color:  #097532;
#             color:  #f1f1f1;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow10_col3 {
#             background-color:  #acdea6;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow10_col4 {
#             background-color:  #f1faee;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow10_col5 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow11_col1 {
#             background-color:  #d1edcb;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow11_col2 {
#             background-color:  #19833e;
#             color:  #f1f1f1;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow11_col3 {
#             background-color:  #eef8ea;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow11_col4 {
#             background-color:  #e7f6e2;
#             color:  #000000;
#         }    #T_e4e51b3e_a763_11eb_ad86_a81e840b27ffrow11_col5 {
#             background-color:  #19833e;
#             color:  #f

# %% [markdown]
# Below are some observations that can be noted from the table above:
#
# - For plant-based food product consumption, the trend has shifted from Europe to Asia (predominantly West Asia) with regard to the top ten consumers, with the exception of the African countries Tunisia, Algeria, and Egypt. The top consumer is Tunisia at 206.79 kg/person/year. Meanwhile, the top consumer of rice is Bangladesh, at 171.73 kg/person/year; it is also to be noted that this country is the world's fourth-largest producer of rice (Mottaleb, Rahut, Kruseman & Erenstein, 2017). Moreover, the top consumer of nuts and peanut butter is the United Arab Emirates, at 23.03 kg/person/year.
# - In most of these countries &mdash; with the notable deviation of Bangladesh in South Asia and Cambodia in Southeast Asia &mdash; the primary plant-based products consumed are wheat and wheat-derived, which account for around 95% of their total plant-based consumption.
# - Similar to the previously observed trends, the ten countries with the lowest record of animal-based food product consumption are mostly in Africa, with the exception of Paraguay and El Salvador in South America and Central America, respectively. Uganda has the lowest plant-based food consumption at 22.55 kg/person/year, followed by Rwanda (which has the lowest overall and animal-based consumption) at 18.56 kg/person/year.
# - This trend may possibly indicate a relationship between the economy of a country and consumption. Consumption is intrinsically tied with the available resources of a country. In particular, countries with enough or above-adequate resources for the production and even participate in the trade of goods also tend to have a more ample supply of food products (either locally produced or imported) for the consumption of their citizens.

# %% [markdown]
# ### *Bar Graphs*

# %% [markdown]
# In order to give a more visual presentation of the data analyzed above, we construct stacked bar graphs to show the animal- and plant-based food product consumption of the respective top 20 countries.

# %%
sorted_animal_country_data = sorted_animal_country_data.head(20)
sorted_plant_country_data = sorted_plant_country_data.head(20)

# %% [markdown]
# *Note that this graph showing the animal-based consumption of the top 20 countries is interactive. Hovering on the sectors or clicking on the legend allows for a more granular look at the data.*

# %%
fig = go.Figure(data = [
    go.Bar(orientation = 'h',
          y = sorted_animal_country_data['country'],
          x = sorted_animal_country_data['Beef'],
          name = 'Beef'),
    go.Bar(orientation = 'h',
          y = sorted_animal_country_data['country'],
          x = sorted_animal_country_data['Eggs'],
          name = 'Eggs'),
    go.Bar(orientation = 'h',
          y = sorted_animal_country_data['country'],
          x = sorted_animal_country_data['Fish'],
          name = 'Fish'),
    go.Bar(orientation = 'h',
          y = sorted_animal_country_data['country'],
          x = sorted_animal_country_data['Lamb & Goat'],
          name = 'Lamb & Goat'),
    go.Bar(orientation = 'h',
          y = sorted_animal_country_data['country'],
          x = sorted_animal_country_data['Milk & Cheese'],
          name = 'Milk & Cheese'),
    go.Bar(orientation = 'h',
          y = sorted_animal_country_data['country'],
          x = sorted_animal_country_data['Pork'],
          name = 'Pork'),
    go.Bar(orientation = 'h',
          y = sorted_animal_country_data['country'],
          x = sorted_animal_country_data['Poultry'],
          name = 'Poultry'),
])

fig.update_layout(barmode = 'stack',
                 yaxis = dict(autorange = 'reversed'),
                 title = "Animal-Based Food Product Consumption of Top 20 Consumers",
                 xaxis_title = "Consumption (kg/person/year)",
                 yaxis_title = "Country")

fig.show()
# Out:
# <div>                            <div id="f989e162-e381-4aca-9e5a-0ed7dd039784" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f989e162-e381-4aca-9e5a-0ed7dd039784")) {                    Plotly.newPlot(                        "f989e162-e381-4aca-9e5a-0ed7dd039784",                        [{"name": "Beef", "orientation": "h", "type": "bar", "x": [19.22, 24.58, 17.67, 4.49, 21.26, 22.35, 36.24, 13.36, 28.46, 29.88, 22.5, 19.83, 33.86, 17.14, 7.19, 13.16, 23.38, 23.81, 18.6, 16.1], "y": ["Finland", "Sweden", "Netherlands", "Lithuania", "Switzerland", "Ireland", "United States", "Iceland", "Denmark", "Luxembourg", "Albania", "Norway", "Australia", "Austria", "Estonia", "Germany", "Kazakhstan", "France", "Italy", "Greece"]}, {"name": "Eggs", "orientation": "h", "type": "bar", "x": [9.55, 13.37, 14.03, 13.11, 10.53, 8.96, 14.58, 8.239999999999998, 15.35, 14.64, 12.45, 11.41, 8.51, 14.68, 12.66, 12.2, 8.29, 13.13, 13.34, 10.13], "y": ["Finland", "Sweden", "Netherlands", "Lithuania", "Switzerland", "Ireland", "United States", "Iceland", "Denmark", "Luxembourg", "Albania", "Norway", "Australia", "Austria", "Estonia", "Germany", "Kazakhstan", "France", "Italy", "Greece"]}, {"name": "Fish", "orientation": "h", "type": "bar", "x": [33.8, 23.86, 18.64, 42.39, 13.48, 17.39, 12.35, 74.41000000000003, 16.49, 23.09, 3.85, 38.18, 17.69, 12.16, 12.78, 11.16, 5.21, 22.91, 15.6, 14.42], "y": ["Finland", "Sweden", "Netherlands", "Lithuania", "Switzerland", "Ireland", "United States", "Iceland", "Denmark", "Luxembourg", "Albania", "Norway", "Australia", "Austria", "Estonia", "Germany", "Kazakhstan", "France", "Italy", "Greece"]}, {"name": "Lamb & Goat", "orientation": "h", "type": "bar", "x": [0.53, 1.41, 0.94, 0.24, 1.42, 4.1, 0.4300000000000001, 21.12, 0.92, 1.6700000000000002, 15.32, 5.34, 9.87, 1.16, 0.44, 0.73, 9.56, 3.28, 0.92, 12.47], "y": ["Finland", "Sweden", "Netherlands", "Lithuania", "Switzerland", "Ireland", "United States", "Iceland", "Denmark", "Luxembourg", "Albania", "Norway", "Australia", "Austria", "Estonia", "Germany", "Kazakhstan", "France", "Italy", "Greece"]}, {"name": "Milk & Cheese", "orientation": "h", "type": "bar", "x": [430.76, 341.23, 341.47, 295.46, 318.69, 291.86, 254.69, 225.82, 277.3, 255.3, 303.72, 261.34000000000003, 234.49, 258.09, 284.85, 258.7, 288.12, 241.31, 246.88, 255.26], "y": ["Finland", "Sweden", "Netherlands", "Lithuania", "Switzerland", "Ireland", "United States", "Iceland", "Denmark", "Luxembourg", "Albania", "Norway", "Australia", "Austria", "Estonia", "Germany", "Kazakhstan", "France", "Italy", "Greece"]}, {"name": "Pork", "orientation": "h", "type": "bar", "x": [36.14, 37.0, 36.36, 45.67, 31.49, 32.4, 27.64, 21.69, 24.87, 43.58, 10.88, 23.51, 24.14, 52.56, 29.68, 51.81, 10.36, 33.05, 40.28, 28.31], "y": ["Finland", "Sweden", "Netherlands", "Lithuania", "Switzerland", "Ireland", "United States", "Iceland", "Denmark", "Luxembourg", "Albania", "Norway", "Australia", "Austria", "Estonia", "Germany", "Kazakhstan", "France", "Italy", "Greece"]}, {"name": "Poultry", "orientation": "h", "type": "bar", "x": [19.87, 16.64, 23.9, 26.84, 16.38, 26.26, 50.01, 26.87, 26.75, 21.37, 13.23, 21.01, 46.12000000000001, 18.610000000000007, 21.110000000000007, 17.75, 18.38, 22.93, 18.610000000000007, 15.739999999999998], "y": ["Finland", "Sweden", "Netherlands", "Lithuania", "Switzerland", "Ireland", "United States", "Iceland", "Denmark", "Luxembourg", "Albania", "Norway", "Australia", "Austria", "Estonia", "Germany", "Kazakhstan", "France", "Italy", "Greece"]}],                        {"barmode": "stack", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar" ...

# %% [markdown]
# This graph corroborates our earlier observation that, especially for most European states, milk and cheese products account for over three-fourths of these countries' animal-based food product consumption.

# %% [markdown]
# *Note that this graph showing the plant-based consumption of the top 20 countries is interactive. Hovering on the sectors or clicking on the legend allows for a more granular look at the data.*

# %%
fig = go.Figure(data = [
    go.Bar(orientation = 'h',
          y = sorted_plant_country_data['country'],
          x = sorted_plant_country_data['Nuts & Peanut Butter'],
          name = 'Nuts & Peanut Butter'),
    go.Bar(orientation = 'h',
          y = sorted_plant_country_data['country'],
          x = sorted_plant_country_data['Rice'],
          name = 'Rice'),
    go.Bar(orientation = 'h',
          y = sorted_plant_country_data['country'],
          x = sorted_plant_country_data['Soybeans'],
          name = 'Soybeans'),
    go.Bar(orientation = 'h',
          y = sorted_plant_country_data['country'],
          x = sorted_plant_country_data['Wheat & Wheat Products'],
          name = 'Wheat & Wheat Products',
          marker_color = 'sandybrown')
])

fig.update_layout(barmode = 'stack',
                 yaxis = dict(autorange = 'reversed'),
                 title = "Plant-Based Food Product Consumption of Top 20 Consumers",
                 xaxis_title = "Consumption (kg/person/year)",
                 yaxis_title = "Country")

fig.show()
# Out:
# <div>                            <div id="a7b59cd2-ecd9-401c-8d4b-cc74178199d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7b59cd2-ecd9-401c-8d4b-cc74178199d4")) {                    Plotly.newPlot(                        "a7b59cd2-ecd9-401c-8d4b-cc74178199d4",                        [{"name": "Nuts & Peanut Butter", "orientation": "h", "type": "bar", "x": [6.34, 12.16, 0.72, 2.08, 7.9700000000000015, 1.82, 3.23, 23.03, 2.47, 1.25, 6.28, 4.92, 2.33, 3.56, 7.63, 6.39, 4.3599999999999985, 5.619999999999999, 4.88, 1.09], "y": ["Tunisia", "Iran", "Bangladesh", "Algeria", "Turkey", "Egypt", "Morocco", "United Arab Emirates", "Georgia", "Cambodia", "Vietnam", "Indonesia", "Mauritius", "Jordan", "Italy", "China", "Albania", "Malta", "South Korea", "Sri Lanka"]}, {"name": "Rice", "orientation": "h", "type": "bar", "x": [1.07, 29.95, 171.73, 2.97, 10.739999999999998, 39.77, 1.1, 56.25, 2.64, 159.1, 144.56, 134.62, 45.56, 19.67, 5.74, 78.17999999999998, 7.78, 4.96, 85.17999999999998, 109.72], "y": ["Tunisia", "Iran", "Bangladesh", "Algeria", "Turkey", "Egypt", "Morocco", "United Arab Emirates", "Georgia", "Cambodia", "Vietnam", "Indonesia", "Mauritius", "Jordan", "Italy", "China", "Albania", "Malta", "South Korea", "Sri Lanka"]}, {"name": "Soybeans", "orientation": "h", "type": "bar", "x": [1.88, 0.0, 0.61, 0.0, 1.71, 0.64, 0.0, 0.08, 0.0, 4.33, 5.75, 1.12, 0.3, 0.02, 0.01, 3.66, 0.0, 0.05, 8.350000000000001, 0.0], "y": ["Tunisia", "Iran", "Bangladesh", "Algeria", "Turkey", "Egypt", "Morocco", "United Arab Emirates", "Georgia", "Cambodia", "Vietnam", "Indonesia", "Mauritius", "Jordan", "Italy", "China", "Albania", "Malta", "South Korea", "Sri Lanka"]}, {"marker": {"color": "sandybrown"}, "name": "Wheat & Wheat Products", "orientation": "h", "type": "bar", "x": [197.5, 153.31, 17.47, 185.42, 169.96, 146.83, 179.7, 101.29, 163.43, 2.74, 10.49, 25.45, 114.02, 136.73999999999998, 146.37, 63.36, 138.64, 139.58, 50.84, 37.01], "y": ["Tunisia", "Iran", "Bangladesh", "Algeria", "Turkey", "Egypt", "Morocco", "United Arab Emirates", "Georgia", "Cambodia", "Vietnam", "Indonesia", "Mauritius", "Jordan", "Italy", "China", "Albania", "Malta", "South Korea", "Sri Lanka"]}],                        {"barmode": "stack", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "typ ...

# %% [markdown]
# This graph corroborates our earlier observation that, for most states in West Asia, wheat and wheat-derived products account for more than 95% of these countries' total plant-based food product consumption. In Southeast Asian and selected South Asian countries, however, rice stands predominant.

# %% [markdown]
# ### 2. Carbon Dioxide Emission

# %% [markdown]
# We pivot the dataset so that the columns are now the food categories and each row corresponds to a country. We also add a column showing the total emission per country.

# %%
co2_data = data.pivot(index = 'country', columns = 'food_category', values = 'co2_emmission').reset_index()

co2_data['TOTAL'] = co2_data['Beef'] + co2_data['Eggs'] + co2_data['Fish'] \
                    + co2_data['Lamb & Goat'] + co2_data['Milk & Cheese'] \
                    + co2_data['Nuts & Peanut Butter'] + co2_data['Pork'] + co2_data['Poultry'] \
                    + co2_data['Rice'] + co2_data['Soybeans'] + co2_data['Wheat & Wheat Products']

print("-- Carbon Dioxide Emission per Country --")
co2_data
# Out:
# -- Carbon Dioxide Emission per Country --
# food_category    country     Beef   Eggs   Fish  Lamb & Goat  Milk & Cheese  \
# 0                Albania   694.30  11.44   6.15       536.50         432.62
# 1                Algeria   172.80   7.40   5.97       269.30         201.60
# 2                 Angola   259.82   1.02  24.33        37.82          17.52
# 3              Argentina  1712.00  10.46   6.96        54.63         277.87
# 4                Armenia   606.67  10.74   6.96       105.76         297.74
# ..                   ...      ...    ...    ...          ...            ...
# 125              Uruguay   897.96  12.07  10.43       288.21         299.89
# 126            Venezuela   798.91   5.17  13.32        11.21         167.78
# 127              Vietnam   229.58   3.53  42.34         4.90          23.30
# 128               Zambia   146.88   3.05   9.90        23.81          13.83
# 129             Zimbabwe   227.42   1.61   4.47        33.62          45.44
#
# food_category  Nuts & Peanut Butter    Pork  Poultry    Rice  Soybeans  \
# 0                              7.72   38.51    14.21    9.96      0.00
# 1                              3.68    0.00     7.97    3.80      0.00
# 2                              4.00   31.47    18.62   10.39      0.23
# 3                              0.87   37.20    41.53   11.22      0.00
# 4                              4.51   34.23    14.34    4.07      0.00
# ..                              ...     ...      ...     ...       ...
# 125                            1.68   59.61    29.49   14.72      0.00
# 126                            0.62   25.59    42.19   29.93      0.00
# 127                           11.12  123.88    13.28  184.99      2.59
# 128                            8.92    5.88     3.53    3.90      3.29
# 129                            3.93    9.38     5.34   12.91      0.24
#
# food_category  Wheat & Wheat Products    TOTAL
# 0                               26.44  1777.85
# 1                               35.36   707.88
# 2                                7.77   412.99
# 3                               19.66  2172.40
# 4                               24.91  1109.93
# ..                                ...      ...
# 125                             20.85  1634.91
# 126                              9.38  1104.10
# 127                              2.00   641.51
# 128                              2.31   225.30
# 129                              5.97   350.33
#
# [130 rows x 13 columns]

# %% [markdown]
# We arrange the entries based on the total emission. As a preliminary visualization, we employ blue gradients to correspond to the amount of carbon dioxide emitted.

# %%
sorted_co2_data = co2_data.sort_values(by = 'TOTAL', ascending = False).reset_index(drop = True)

print("-- Carbon Dioxide Emission per Country (Sorted) --")
sorted_co2_data.style.background_gradient(cmap = 'Blues')
# Out:
# -- Carbon Dioxide Emission per Country (Sorted) --
# <style  type="text/css" >
#     #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow0_col2 {
#             background-color:  #4d99ca;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow0_col3 {
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow0_col4 {
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow0_col5 {
#             background-color:  #81badb;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow0_col6 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow0_col7 {
#             background-color:  #d8e7f5;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow0_col8 {
#             background-color:  #4594c7;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow0_col9 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow0_col10 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow0_col11 {
#             background-color:  #66abd4;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow0_col12 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow1_col1 {
#             background-color:  #4997c9;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow1_col2 {
#             background-color:  #84bcdb;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow1_col3 {
#             background-color:  #e4eff9;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow1_col4 {
#             background-color:  #79b5d9;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow1_col5 {
#             background-color:  #5da5d1;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow1_col6 {
#             background-color:  #9fcae1;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow1_col7 {
#             background-color:  #a3cce3;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow1_col8 {
#             background-color:  #2474b7;
#             color:  #f1f1f1;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow1_col9 {
#             background-color:  #ebf3fb;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow1_col10 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow1_col11 {
#             background-color:  #a6cee4;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow1_col12 {
#             background-color:  #084e98;
#             color:  #f1f1f1;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow2_col1 {
#             background-color:  #95c5df;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow2_col2 {
#             background-color:  #3c8cc3;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow2_col3 {
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow2_col4 {
#             background-color:  #2777b8;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow2_col5 {
#             background-color:  #2e7ebc;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow2_col6 {
#             background-color:  #d3e4f3;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow2_col7 {
#             background-color:  #d7e6f5;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow2_col8 {
#             background-color:  #cfe1f2;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow2_col9 {
#             background-color:  #eff6fc;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow2_col10 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow2_col11 {
#             background-color:  #2f7fbc;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow2_col12 {
#             background-color:  #1562a9;
#             color:  #f1f1f1;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow3_col1 {
#             background-color:  #95c5df;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow3_col2 {
#             background-color:  #66abd4;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow3_col3 {
#             background-color:  #e1edf8;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow3_col4 {
#             background-color:  #084b93;
#             color:  #f1f1f1;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow3_col5 {
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow3_col6 {
#             background-color:  #a5cde3;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow3_col7 {
#             background-color:  #abd0e6;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow3_col8 {
#             background-color:  #58a1cf;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow3_col9 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow3_col10 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow3_col11 {
#             background-color:  #9cc9e1;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow3_col12 {
#             background-color:  #1966ad;
#             color:  #f1f1f1;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow4_col1 {
#             background-color:  #cadef0;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow4_col2 {
#             background-color:  #8abfdd;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow4_col3 {
#             background-color:  #8fc2de;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow4_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow4_col5 {
#             background-color:  #64a9d3;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow4_col6 {
#             background-color:  #d7e6f5;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow4_col7 {
#             background-color:  #afd1e7;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow4_col8 {
#             background-color:  #8abfdd;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow4_col9 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow4_col10 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow4_col11 {
#             background-color:  #a3cce3;
#             color:  #000000;
#         }    #T_e67e18f6_a763_11eb_9bc0_a81e840b27ffrow4_col12 {
#             background-color:  #1a68ae;
#             color

# %% [markdown]
# Below are some observations that can be noted from the table above:
# - Unlike consumption, emission has no clear trend as regards the ten countries that registered the highest figures. They come from different regions: South America (Argentina, Uruguay, and Brazil), Oceania (Australia and New Zealand), Europe (Albania, Iceland, and Luxembourg), Central Asia (Kazakhstan), and the United States. The highest emission is recorded by Argentina at 2172.4 kg CO<sub>2</sub>/kg/year.
# - Beef and milk and cheese are the primary contributory products to emission although the proportion of emission due to the latter is less pronounced compared to their consumption. The overall top emitter Argentina is also the top emitter of beef-related CO<sub>2</sub> at 1712 kg CO<sub>2</sub>/kg/year, accounting for 78.82% of its total emission. Meanwhile, Iceland, which also happens to be the top consumer of lamb and goat food products, is also the top emitter for the same food category, at 739.62 kg CO<sub>2</sub>/kg/year, which corresponds to around 42.72% of its total emission.
# - On the other hand, the ten countries with the lowest record of food product-related emission are all in Africa, with Mozambique recording the lowest emission (141.4 kg CO<sub>2</sub>/person/year), followed by Rwanda at 181.63 kg CO<sub>2</sub>/person/year. Interestingly, Rwanda also happens to be the lowest food product consumer. In fact, there is a noticeable overlap between the lowest emitters although their placements are shuffled. The Republic of the Congo is the only country in the ten lowest emitters that is not in the ten lowest consumers as well (Cameroon is included instead).

# %% [markdown]
# ### *Animal-Based Food Products*

# %% [markdown]
# We now zero in on the food products that are derived from animals.

# %%
animal_co2_data = co2_data[animal_products]

animal_co2_data['TOTAL'] = animal_co2_data['Beef'] + animal_co2_data['Eggs'] + animal_co2_data['Fish'] \
                               + animal_co2_data['Lamb & Goat'] + animal_co2_data['Milk & Cheese'] \
                               + animal_co2_data['Pork'] + animal_co2_data['Poultry']

print("-- Animal-Based Food Product-Related Emission per Country --")
animal_co2_data
# Out:
# -- Animal-Based Food Product-Related Emission per Country --
# food_category    country     Beef   Eggs   Fish  Lamb & Goat  Milk & Cheese  \
# 0                Albania   694.30  11.44   6.15       536.50         432.62
# 1                Algeria   172.80   7.40   5.97       269.30         201.60
# 2                 Angola   259.82   1.02  24.33        37.82          17.52
# 3              Argentina  1712.00  10.46   6.96        54.63         277.87
# 4                Armenia   606.67  10.74   6.96       105.76         297.74
# ..                   ...      ...    ...    ...          ...            ...
# 125              Uruguay   897.96  12.07  10.43       288.21         299.89
# 126            Venezuela   798.91   5.17  13.32        11.21         167.78
# 127              Vietnam   229.58   3.53  42.34         4.90          23.30
# 128               Zambia   146.88   3.05   9.90        23.81          13.83
# 129             Zimbabwe   227.42   1.61   4.47        33.62          45.44
#
# food_category    Pork  Poultry    TOTAL
# 0               38.51    14.21  1733.73
# 1                0.00     7.97   665.04
# 2               31.47    18.62   390.60
# 3               37.20    41.53  2140.65
# 4               34.23    14.34  1076.44
# ..                ...      ...      ...
# 125             59.61    29.49  1597.66
# 126             25.59    42.19  1064.17
# 127            123.88    13.28   440.81
# 128              5.88     3.53   206.88
# 129              9.38     5.34   327.28
#
# [130 rows x 9 columns]

# %% [markdown]
# We arrange the entries based on the total emission. As a preliminary visualization, we employ red gradients to correspond to the amount of carbon dioxide emitted.

# %%
sorted_animal_co2_data = animal_co2_data.sort_values(by = 'TOTAL', ascending = False).reset_index(drop = True)

print("-- Animal-Based Food Product-Related Emission per Country (Sorted) --")
sorted_animal_co2_data.style.background_gradient(cmap = 'Reds')
# Out:
# -- Animal-Based Food Product-Related Emission per Country (Sorted) --
# <style  type="text/css" >
#     #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow0_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow0_col2 {
#             background-color:  #f24734;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow0_col3 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow0_col4 {
#             background-color:  #fee9df;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow0_col5 {
#             background-color:  #fb7b5b;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow0_col6 {
#             background-color:  #fdd7c6;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow0_col7 {
#             background-color:  #f03f2e;
#             color:  #f1f1f1;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow0_col8 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow1_col1 {
#             background-color:  #f14331;
#             color:  #f1f1f1;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow1_col2 {
#             background-color:  #fb7d5d;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow1_col3 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow1_col4 {
#             background-color:  #fb7555;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow1_col5 {
#             background-color:  #f75b40;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow1_col6 {
#             background-color:  #fc9777;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow1_col7 {
#             background-color:  #cf1c1f;
#             color:  #f1f1f1;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow1_col8 {
#             background-color:  #a10e15;
#             color:  #f1f1f1;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow2_col1 {
#             background-color:  #fc8b6b;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow2_col2 {
#             background-color:  #e93529;
#             color:  #f1f1f1;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow2_col3 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow2_col4 {
#             background-color:  #d21f20;
#             color:  #f1f1f1;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow2_col5 {
#             background-color:  #d92523;
#             color:  #f1f1f1;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow2_col6 {
#             background-color:  #fdd5c4;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow2_col7 {
#             background-color:  #fdc9b3;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow2_col8 {
#             background-color:  #bb141a;
#             color:  #f1f1f1;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow3_col1 {
#             background-color:  #fc8b6b;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow3_col2 {
#             background-color:  #fa6547;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow3_col3 {
#             background-color:  #fee3d6;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow3_col4 {
#             background-color:  #9a0c14;
#             color:  #f1f1f1;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow3_col5 {
#             background-color:  #fca689;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow3_col6 {
#             background-color:  #fca082;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow3_col7 {
#             background-color:  #f6553c;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow3_col8 {
#             background-color:  #be151a;
#             color:  #f1f1f1;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow4_col1 {
#             background-color:  #fcc2aa;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow4_col2 {
#             background-color:  #fc8262;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow4_col3 {
#             background-color:  #fc8666;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow4_col4 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow4_col5 {
#             background-color:  #f96245;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow4_col6 {
#             background-color:  #fca486;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow4_col7 {
#             background-color:  #fc8262;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow4_col8 {
#             background-color:  #be151a;
#             color:  #f1f1f1;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow5_col1 {
#             background-color:  #e93529;
#             color:  #f1f1f1;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow5_col2 {
#             background-color:  #c8171c;
#             color:  #f1f1f1;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow5_col3 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow5_col4 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow5_col5 {
#             background-color:  #f34935;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow5_col6 {
#             background-color:  #fc8666;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow5_col7 {
#             background-color:  #bc141a;
#             color:  #f1f1f1;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow5_col8 {
#             background-color:  #c3161b;
#             color:  #f1f1f1;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow6_col1 {
#             background-color:  #f96346;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow6_col2 {
#             background-color:  #de2b25;
#             color:  #f1f1f1;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow6_col3 {
#             background-color:  #fff0e8;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow6_col4 {
#             background-color:  #fc8e6e;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow6_col5 {
#             background-color:  #fb6e4e;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow6_col6 {
#             background-color:  #fcbba1;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow6_col7 {
#             background-color:  #fc7f5f;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow6_col8 {
#             background-color:  #cf1c1f;
#             color:  #f1f1f1;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow7_col1 {
#             background-color:  #f85d42;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow7_col2 {
#             background-color:  #c7171c;
#             color:  #f1f1f1;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow7_col3 {
#             background-color:  #fee0d2;
#             color:  #000000;
#         }    #T_e70a7f36_a763_11eb_846f_a81e840b27ffrow7_col4 {
#             background-color:  #fee8dd;
#             color:  #000000;

# %% [markdown]
# Below are some observations that can be noted from the table above:
#
# - The ten countries that registered the highest figures as regards animal-based food product-related emission are the same as those for food product-related emission in general. In fact, their placements also remained constant, with the sole exception of Brazil and Luxembourg exchanging positions (#8 and #9).
# - Reiterating the point mentioned in the previous trend, these countries come from different regions: South America (Argentina, Uruguay, and Brazil), Oceania (Australia and New Zealand), Europe (Albania, Iceland, and Luxembourg), Central Asia (Kazakhstan), and the United States. The highest animal-based food product-related emission is recorded by Argentina at 2140.65 kg CO<sub>2</sub>/kg/year.
# - Beef and milk and cheese are the primary contributory products to emission although the proportion of emission due to the latter is less pronounced compared to their consumption. For instance, the overall top emitter Argentina is also the top emitter of beef-related CO<sub>2</sub> at 1712 kg CO<sub>2</sub>/kg/year, accounting for 80% of its total animal-based food product-related emission. Iceland, which also happens to be the top consumer of lamb and goat food products, is also the top emitter for the same food category, at 739.62 kg CO<sub>2</sub>/kg/year, which corresponds to around 43.37% of its total animal-based food product-related emission.
# - On the other hand, most of the ten countries with the lowest animal-based food product-related emission are in Africa, with Liberia recording the lowest at 77.44 kg CO<sub>2</sub>/person/year. The non-African countries are the South Asian countries Bangladesh and India and the Southeast Asian country Indonesia. It may be fitting to note that India is a predominently Hindu country, which bans the slaughter of cattle (including cows) in most of its regions; cow-related products, like beef and dairy, are among the highest contributors of carbon footprint.

# %% [markdown]
# ### ***Plant-Based Food Products***

# %% [markdown]
# We now zero in on the food products that are derived from plants.

# %%
plant_co2_data = co2_data[plant_products]

plant_co2_data['TOTAL'] = plant_co2_data['Nuts & Peanut Butter'] \
                              + plant_co2_data['Rice'] + plant_co2_data['Soybeans'] \
                              + plant_co2_data['Wheat & Wheat Products']
    
print("-- Plant-Based Food Product-Related Emission per Country --")
plant_co2_data
# Out:
# -- Plant-Based Food Product-Related Emission per Country --
# food_category    country  Nuts & Peanut Butter    Rice  Soybeans  \
# 0                Albania                  7.72    9.96      0.00
# 1                Algeria                  3.68    3.80      0.00
# 2                 Angola                  4.00   10.39      0.23
# 3              Argentina                  0.87   11.22      0.00
# 4                Armenia                  4.51    4.07      0.00
# ..                   ...                   ...     ...       ...
# 125              Uruguay                  1.68   14.72      0.00
# 126            Venezuela                  0.62   29.93      0.00
# 127              Vietnam                 11.12  184.99      2.59
# 128               Zambia                  8.92    3.90      3.29
# 129             Zimbabwe                  3.93   12.91      0.24
#
# food_category  Wheat & Wheat Products   TOTAL
# 0                               26.44   44.12
# 1                               35.36   42.84
# 2                                7.77   22.39
# 3                               19.66   31.75
# 4                               24.91   33.49
# ..                                ...     ...
# 125                             20.85   37.25
# 126                              9.38   39.93
# 127                              2.00  200.70
# 128                              2.31   18.42
# 129                              5.97   23.05
#
# [130 rows x 6 columns]

# %% [markdown]
# We arrange the entries based on the total emission. As a preliminary visualization, we employ green gradients to correspond to the amount of carbon dioxide emitted.

# %%
sorted_plant_co2_data = plant_co2_data.sort_values(by = 'TOTAL', ascending = False).reset_index(drop = True)

print("-- Plant-Based Food Product-Related Emission per Country (Sorted) --")
sorted_plant_co2_data.style.background_gradient(cmap = 'Greens')
# Out:
# -- Plant-Based Food Product-Related Emission per Country (Sorted) --
# <style  type="text/css" >
#     #T_e760f306_a763_11eb_a716_a81e840b27ffrow0_col1 {
#             background-color:  #f4fbf1;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow0_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow0_col3 {
#             background-color:  #f2faef;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow0_col4 {
#             background-color:  #ecf8e8;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow0_col5 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow1_col1 {
#             background-color:  #f1faee;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow1_col2 {
#             background-color:  #005b25;
#             color:  #f1f1f1;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow1_col3 {
#             background-color:  #c6e8bf;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow1_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow1_col5 {
#             background-color:  #005c25;
#             color:  #f1f1f1;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow2_col1 {
#             background-color:  #c2e7bb;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow2_col2 {
#             background-color:  #097532;
#             color:  #f1f1f1;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow2_col3 {
#             background-color:  #acdea6;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow2_col4 {
#             background-color:  #f1faee;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow2_col5 {
#             background-color:  #00682a;
#             color:  #f1f1f1;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow3_col1 {
#             background-color:  #d1edcb;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow3_col2 {
#             background-color:  #19833e;
#             color:  #f1f1f1;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow3_col3 {
#             background-color:  #eef8ea;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow3_col4 {
#             background-color:  #e7f6e2;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow3_col5 {
#             background-color:  #0e7936;
#             color:  #f1f1f1;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow4_col1 {
#             background-color:  #d6efd0;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow4_col2 {
#             background-color:  #1d8640;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow4_col3 {
#             background-color:  #f4fbf2;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow4_col4 {
#             background-color:  #f5fbf2;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow4_col5 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow5_col1 {
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow5_col2 {
#             background-color:  #309950;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow5_col3 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow5_col4 {
#             background-color:  #e8f6e4;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow5_col5 {
#             background-color:  #2f974e;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow6_col1 {
#             background-color:  #eff9ec;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow6_col2 {
#             background-color:  #37a055;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow6_col3 {
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow6_col4 {
#             background-color:  #f1faee;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow6_col5 {
#             background-color:  #38a156;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow7_col1 {
#             background-color:  #f1faee;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow7_col2 {
#             background-color:  #3ea75a;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow7_col3 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow7_col4 {
#             background-color:  #d9f0d3;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow7_col5 {
#             background-color:  #3ca559;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow8_col1 {
#             background-color:  #cbeac4;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow8_col2 {
#             background-color:  #4bb062;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow8_col3 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow8_col4 {
#             background-color:  #f3faf0;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow8_col5 {
#             background-color:  #43ac5e;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow9_col1 {
#             background-color:  #daf0d4;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow9_col2 {
#             background-color:  #5ab769;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow9_col3 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow9_col4 {
#             background-color:  #ecf8e8;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow9_col5 {
#             background-color:  #53b466;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow10_col1 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow10_col2 {
#             background-color:  #4db163;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow10_col3 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow10_col4 {
#             background-color:  #f2faf0;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow10_col5 {
#             background-color:  #56b567;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow11_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow11_col2 {
#             background-color:  #b1e0ab;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow11_col3 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow11_col4 {
#             background-color:  #72c375;
#             color:  #000000;
#         }    #T_e760f306_a763_11eb_a716_a81e840b27ffrow11_col5 {
#             background-color:  #58b668;
#             color:  #0

# %% [markdown]
# Below are some observations that can be noted from the table above:
#
# - For plant-based food product consumption, the ten countries that recorded the highest figures have shifted to Southeast Asia, the predominant rice-producing belt in the world, with the exception of the South Asian countries Sri Lanka and Bangladesh &mdash; which also happens to be the top consumer of rice and its fourth-largest producer (Mottaleb, Rahut, Kruseman & Erenstein, 2017) &mdash; and the African states Sierra Leone and Guinea. The highest emission is from Bangladesh at 224.63 kg CO<sub>2</sub>/person/year.
# - In these countries, emission due to rice far outweighs the others, with close to 98% of the total plant-based food product-related emission attributed to the said crop.
# - The Philippines is the 6<sup>th</sup> highest emitter of plant-based food product-related carbon dioxide at 160.95 kg CO<sub>2</sub>/person/year.
# - Similar to the previously observed trends, the ten countries with the lowest record of animal-based food product consumption are mostly in Africa, with the exception of Paraguay, Guatemala Mexico in South America, Central America, and North America, respectively. Ethopia has the lowest plant-based food product-related emission at 11.18 kg CO<sub>2</sub>/person/year, followed by Uganda &mdash; which also happens to be the lowest plant-based food product-related consumer &mdash; at 14.54 kg CO<sub>2</sub>/person/year.

# %% [markdown]
# ### *Bar Graphs*

# %% [markdown]
# In order to give a more visual presentation of the data analyzed above, we construct stacked bar graphs to show the animal- and plant-based food product-related emission of the respective top 20 countries.

# %%
sorted_animal_co2_data = sorted_animal_co2_data.head(20)
sorted_plant_co2_data = sorted_plant_co2_data.head(20)

# %% [markdown]
# *Note that this graph showing the animal-based food product-related emission of the top 20 countries is interactive. Hovering on the sectors or clicking on the legend allows for a more granular look at the data.*

# %%
fig = go.Figure(data = [
    go.Bar(orientation = 'h',
          y = sorted_animal_co2_data['country'],
          x = sorted_animal_co2_data['Beef'],
          name = 'Beef'),
    go.Bar(orientation = 'h',
          y = sorted_animal_co2_data['country'],
          x = sorted_animal_co2_data['Eggs'],
          name = 'Eggs'),
    go.Bar(orientation = 'h',
          y = sorted_animal_co2_data['country'],
          x = sorted_animal_co2_data['Fish'],
          name = 'Fish'),
    go.Bar(orientation = 'h',
          y = sorted_animal_co2_data['country'],
          x = sorted_animal_co2_data['Lamb & Goat'],
          name = 'Lamb & Goat'),
    go.Bar(orientation = 'h',
          y = sorted_animal_co2_data['country'],
          x = sorted_animal_co2_data['Milk & Cheese'],
          name = 'Milk & Cheese'),
    go.Bar(orientation = 'h',
          y = sorted_animal_co2_data['country'],
          x = sorted_animal_co2_data['Pork'],
          name = 'Pork'),
    go.Bar(orientation = 'h',
          y = sorted_animal_co2_data['country'],
          x = sorted_animal_co2_data['Poultry'],
          name = 'Poultry'),
])

fig.update_layout(barmode = 'stack',
                 yaxis = dict(autorange = 'reversed'),
                 title = "Animal-Based Food Product-Related CO<sub>2</sub> Emission of Top 20 Emitters",
                 xaxis_title = "Emission (kg CO<sub>2</sub>/person/year)",
                 yaxis_title = "Country")

fig.show()
# Out:
# <div>                            <div id="484c0616-10c4-4f18-ac06-776061e979d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("484c0616-10c4-4f18-ac06-776061e979d8")) {                    Plotly.newPlot(                        "484c0616-10c4-4f18-ac06-776061e979d8",                        [{"name": "Beef", "orientation": "h", "type": "bar", "x": [1712.0, 1044.85, 694.3, 693.99, 412.26, 1118.29, 897.9599999999998, 922.03, 1211.1699999999996, 721.4599999999998, 758.49, 878.22, 1022.94, 496.81, 593.09, 689.6700000000002, 796.75, 933.45, 734.73, 953.51], "y": ["Argentina", "Australia", "Albania", "New Zealand", "Iceland", "United States", "Uruguay", "Luxembourg", "Brazil", "Kazakhstan", "Sweden", "Denmark", "Bermuda", "Greece", "Finland", "Ireland", "Hong Kong", "Canada", "France", "French Polynesia"]}, {"name": "Eggs", "orientation": "h", "type": "bar", "x": [10.46, 7.8199999999999985, 11.44, 9.1, 7.57, 13.39, 12.07, 13.45, 8.25, 7.619999999999999, 12.28, 14.1, 13.71, 9.31, 8.77, 8.229999999999999, 13.32, 11.9, 12.06, 8.04], "y": ["Argentina", "Australia", "Albania", "New Zealand", "Iceland", "United States", "Uruguay", "Luxembourg", "Brazil", "Kazakhstan", "Sweden", "Denmark", "Bermuda", "Greece", "Finland", "Ireland", "Hong Kong", "Canada", "France", "French Polynesia"]}, {"name": "Fish", "orientation": "h", "type": "bar", "x": [6.96, 28.25, 6.15, 32.51, 118.81, 19.72, 10.43, 36.87, 15.98, 8.32, 38.1, 26.33, 53.04, 23.02, 53.97, 27.77, 67.76, 23.25, 36.58, 62.19000000000001], "y": ["Argentina", "Australia", "Albania", "New Zealand", "Iceland", "United States", "Uruguay", "Luxembourg", "Brazil", "Kazakhstan", "Sweden", "Denmark", "Bermuda", "Greece", "Finland", "Ireland", "Hong Kong", "Canada", "France", "French Polynesia"]}, {"name": "Lamb & Goat", "orientation": "h", "type": "bar", "x": [54.63, 345.6500000000001, 536.5, 662.23, 739.62, 15.06, 288.21, 58.48, 21.71, 334.79, 49.38, 32.22000000000001, 94.9, 436.7, 18.56, 143.58, 77.74000000000002, 33.97, 114.87, 99.11], "y": ["Argentina", "Australia", "Albania", "New Zealand", "Iceland", "United States", "Uruguay", "Luxembourg", "Brazil", "Kazakhstan", "Sweden", "Denmark", "Bermuda", "Greece", "Finland", "Ireland", "Hong Kong", "Canada", "France", "French Polynesia"]}, {"name": "Milk & Cheese", "orientation": "h", "type": "bar", "x": [277.87, 334.01, 432.62, 195.5, 321.66, 362.78, 299.89, 363.65, 212.63, 410.4, 486.05, 394.99, 136.12, 363.59, 613.57, 415.73, 150.76999999999995, 267.46, 343.72, 133.26999999999998], "y": ["Argentina", "Australia", "Albania", "New Zealand", "Iceland", "United States", "Uruguay", "Luxembourg", "Brazil", "Kazakhstan", "Sweden", "Denmark", "Bermuda", "Greece", "Finland", "Ireland", "Hong Kong", "Canada", "France", "French Polynesia"]}, {"name": "Pork", "orientation": "h", "type": "bar", "x": [37.2, 85.44000000000003, 38.51, 78.9, 76.77, 97.83, 59.61, 154.25, 44.6, 36.67, 130.96, 88.03, 99.96, 100.2, 127.92, 114.68, 237.54, 80.74000000000002, 116.98, 52.21], "y": ["Argentina", "Australia", "Albania", "New Zealand", "Iceland", "United States", "Uruguay", "Luxembourg", "Brazil", "Kazakhstan", "Sweden", "Denmark", "Bermuda", "Greece", "Finland", "Ireland", "Hong Kong", "Canada", "France", "French Polynesia"]}, {"name": "Poultry", "orientation": "h", "type": "bar", "x": [41.53, 49.54, 14.21, 37.58, 28.86, 53.72000000000001, 29.49, 22.96, 48.34, 19.74, 17.87, 28.73, 35.04, 16.91, 21.34, 28.21, 58.93, 39.4, 24.630000000000006, 53.23], "y": ["Argentina", "Australia", "Albania", "New Zealand", "Iceland", "United States", "Uruguay", "Luxembourg", "Brazil", "Kazakhstan", "Sweden", "Denmark", "Bermuda", "Greece", "Finland", "Ireland", "Hong Kong", "Canada", "France", "French Polynesia"]}],                        {"barmode": "stac ...

# %% [markdown]
# This graph corroborates our earlier observation that, for these states, beef accounts for an significant majority of the food product consumption; it is followed by milk and cheese derivatives. Interestingly, beef is not among the most consumed products in these countries, which points towards the strong carbon footprint left by the production of this food product.

# %% [markdown]
# *Note that this graph showing the plant-based food product-related emission of the top 20 countries is interactive. Hovering on the sectors or clicking on the legend allows for a more granular look at the data.*

# %%
fig = go.Figure(data = [
    go.Bar(orientation = 'h',
          y = sorted_plant_co2_data['country'],
          x = sorted_plant_co2_data['Nuts & Peanut Butter'],
          name = 'Nuts & Peanut Butter'),
    go.Bar(orientation = 'h',
          y = sorted_plant_co2_data['country'],
          x = sorted_plant_co2_data['Rice'],
          name = 'Rice'),
    go.Bar(orientation = 'h',
          y = sorted_plant_co2_data['country'],
          x = sorted_plant_co2_data['Soybeans'],
          name = 'Soybeans'),
    go.Bar(orientation = 'h',
          y = sorted_plant_co2_data['country'],
          x = sorted_plant_co2_data['Wheat & Wheat Products'],
          name = 'Wheat & Wheat Products',
          marker_color = 'sandybrown')
])

fig.update_layout(barmode = 'stack',
                 yaxis = dict(autorange = 'reversed'),
                 title = "Plant-Based Food Product-Related CO<sub>2</sub> Emission of Top 20 Emitters",
                 xaxis_title = "Emission (kg CO<sub>2</sub>/person/year)",
                 yaxis_title = "Country")
fig.show()
# Out:
# <div>                            <div id="120ff6ab-9ba3-4010-9d69-3a902620bde8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("120ff6ab-9ba3-4010-9d69-3a902620bde8")) {                    Plotly.newPlot(                        "120ff6ab-9ba3-4010-9d69-3a902620bde8",                        [{"name": "Nuts & Peanut Butter", "orientation": "h", "type": "bar", "x": [1.27, 2.21, 11.12, 8.709999999999999, 7.9700000000000015, 3.68, 2.66, 1.93, 9.86, 7.33, 0.62, 40.76000000000001, 8.639999999999999, 4.28, 2.32, 11.31, 5.13, 28.02, 7.13, 3.4], "y": ["Bangladesh", "Cambodia", "Vietnam", "Indonesia", "Myanmar", "Philippines", "Thailand", "Sri Lanka", "Sierra Leone", "Guinea", "Madagascar", "United Arab Emirates", "South Korea", "Nepal", "Liberia", "China", "Malaysia", "Maldives", "Senegal", "India"]}, {"name": "Rice", "orientation": "h", "type": "bar", "x": [219.76, 203.6, 184.99, 172.26999999999995, 169.94, 152.85000000000005, 146.62, 140.41, 132.19, 124.28, 131.20999999999998, 71.98, 109.0, 112.29, 121.25, 100.05, 103.98, 64.92, 92.51, 88.93], "y": ["Bangladesh", "Cambodia", "Vietnam", "Indonesia", "Myanmar", "Philippines", "Thailand", "Sri Lanka", "Sierra Leone", "Guinea", "Madagascar", "United Arab Emirates", "South Korea", "Nepal", "Liberia", "China", "Malaysia", "Maldives", "Senegal", "India"]}, {"name": "Soybeans", "orientation": "h", "type": "bar", "x": [0.27, 1.95, 2.59, 0.5, 0.17, 0.01, 0.96, 0.0, 0.0, 0.0, 0.0, 0.04, 3.76, 0.0, 0.28, 1.65, 0.02, 0.09, 0.0, 0.18], "y": ["Bangladesh", "Cambodia", "Vietnam", "Indonesia", "Myanmar", "Philippines", "Thailand", "Sri Lanka", "Sierra Leone", "Guinea", "Madagascar", "United Arab Emirates", "South Korea", "Nepal", "Liberia", "China", "Malaysia", "Maldives", "Senegal", "India"]}, {"marker": {"color": "sandybrown"}, "name": "Wheat & Wheat Products", "orientation": "h", "type": "bar", "x": [3.33, 0.52, 2.0, 4.85, 1.1900000000000002, 4.41, 2.08, 7.06, 1.66, 3.54, 1.72, 19.32, 9.7, 9.62, 2.09, 12.08, 9.73, 14.83, 7.119999999999999, 11.55], "y": ["Bangladesh", "Cambodia", "Vietnam", "Indonesia", "Myanmar", "Philippines", "Thailand", "Sri Lanka", "Sierra Leone", "Guinea", "Madagascar", "United Arab Emirates", "South Korea", "Nepal", "Liberia", "China", "Malaysia", "Maldives", "Senegal", "India"]}],                        {"barmode": "stack", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777 ...

# %% [markdown]
# This graph corroborates our earlier observation that, for these states (which are mostly located in Asia), emission due to rice far outweighs the others, with close to 98% of the total plant-based food product-related emission ascribed to the said crop.

# %% [markdown]
# <hr/>

# %% [markdown]
# ## B. By Food Product

# %% [markdown]
# We now proceed to an identification of the trends related to both consumption and carbon dioxide emission based on the food product.

# %%
food_data = data.groupby(['food_category'], as_index = False).sum()

print("-- Consumption and Carbon Dioxide Emission By Food Product --")
food_data
# Out:
# -- Consumption and Carbon Dioxide Emission By Food Product --
#              food_category  consumption  co2_emmission
# 0                     Beef      1576.04       48633.26
# 1                     Eggs      1061.29         974.95
# 2                     Fish      2247.32        3588.22
# 3              Lamb & Goat       338.02       11837.38
# 4            Milk & Cheese     16350.71       23290.00
# ..                     ...          ...            ...
# 6                     Pork      2096.08        7419.11
# 7                  Poultry      2758.50        2963.16
# 8                     Rice      3818.77        4886.91
# 9                 Soybeans       111.87          50.35
# 10  Wheat & Wheat Products      9301.44        1773.78
#
# [11 rows x 3 columns]

# %% [markdown]
# ### 1. Consumption

# %% [markdown]
# We arrange the food categories based on the total consumption. As a preliminary visualization, we employ blue gradients to correspond to the amount of food products consumed.

# %%
sorted_consumption_food_data = food_data.sort_values(by = 'consumption', ascending = False).reset_index(drop = True)
sorted_consumption_food_data.drop(columns = ['co2_emmission'], axis = 1, inplace = True)

sorted_consumption_food_data.style.background_gradient(cmap = 'Blues')
# Out:
# <style  type="text/css" >
#     #T_e7e2595c_a763_11eb_8990_a81e840b27ffrow0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_e7e2595c_a763_11eb_8990_a81e840b27ffrow1_col1 {
#             background-color:  #56a0ce;
#             color:  #000000;
#         }    #T_e7e2595c_a763_11eb_8990_a81e840b27ffrow2_col1 {
#             background-color:  #cadef0;
#             color:  #000000;
#         }    #T_e7e2595c_a763_11eb_8990_a81e840b27ffrow3_col1 {
#             background-color:  #d7e6f5;
#             color:  #000000;
#         }    #T_e7e2595c_a763_11eb_8990_a81e840b27ffrow4_col1 {
#             background-color:  #ddeaf7;
#             color:  #000000;
#         }    #T_e7e2595c_a763_11eb_8990_a81e840b27ffrow5_col1 {
#             background-color:  #dfebf7;
#             color:  #000000;
#         }    #T_e7e2595c_a763_11eb_8990_a81e840b27ffrow6_col1 {
#             background-color:  #e5eff9;
#             color:  #000000;
#         }    #T_e7e2595c_a763_11eb_8990_a81e840b27ffrow7_col1 {
#             background-color:  #ecf4fb;
#             color:  #000000;
#         }    #T_e7e2595c_a763_11eb_8990_a81e840b27ffrow8_col1 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_e7e2595c_a763_11eb_8990_a81e840b27ffrow9_col1 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }    #T_e7e2595c_a763_11eb_8990_a81e840b27ffrow10_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }</style><table id="T_e7e2595c_a763_11eb_8990_a81e840b27ff" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >food_category</th>        <th class="col_heading level0 col1" >consumption</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e7e2595c_a763_11eb_8990_a81e840b27fflevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e7e2595c_a763_11eb_8990_a81e840b27ffrow0_col0" class="data row0 col0" >Milk & Cheese</td>
#                         <td id="T_e7e2595c_a763_11eb_8990_a81e840b27ffrow0_col1" class="data row0 col1" >16350.710000</td>
#             </tr>
#             <tr>
#                         <th id="T_e7e2595c_a763_11eb_8990_a81e840b27fflevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e7e2595c_a763_11eb_8990_a81e840b27ffrow1_col0" class="data row1 col0" >Wheat & Wheat Products</td>
#                         <td id="T_e7e2595c_a763_11eb_8990_a81e840b27ffrow1_col1" class="data row1 col1" >9301.440000</td>
#             </tr>
#             <tr>
#                         <th id="T_e7e2595c_a763_11eb_8990_a81e840b27fflevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e7e2595c_a763_11eb_8990_a81e840b27ffrow2_col0" class="data row2 col0" >Rice</td>
#                         <td id="T_e7e2595c_a763_11eb_8990_a81e840b27ffrow2_col1" class="data row2 col1" >3818.770000</td>
#             </tr>
#             <tr>
#                         <th id="T_e7e2595c_a763_11eb_8990_a81e840b27fflevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e7e2595c_a763_11eb_8990_a81e840b27ffrow3_col0" class="data row3 col0" >Poultry</td>
#                         <td id="T_e7e2595c_a763_11eb_8990_a81e840b27ffrow3_col1" class="data row3 col1" >2758.500000</td>
#             </tr>
#             <tr>
#                         <th id="T_e7e2595c_a763_11eb_8990_a81e840b27fflevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e7e2595c_a763_11eb_8990_a81e840b27ffrow4_col0" class="data row4 col0" >Fish</td>
#                         <td id="T_e7e2595c_a763_11eb_8990_a81e840b27ffrow4_col1" class="data row4 col1" >2247.320000</td>
#             </tr>
#             <tr>
#                         <th id="T_e7e2595c_a763_11eb_8990_a81e840b27fflevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e7e2595c_a763_11eb_8990_a81e840b27ffrow5_col0" class="data row5 col0" >Pork</td>
#                         <td id="T_e7e2595c_a763_11eb_8990_a81e840b27ffrow5_col1" class="data row5 col1" >2096.080000</td>
#             </tr>
#             <tr>
#                         <th id="T_e7e2595c_a763_11eb_8990_a81e840b27fflevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_e7e2595c_a763_11eb_8990_a81e840b27ffrow6_col0" class="data row6 col0" >Beef</td>
#                         <td id="T_e7e2595c_a763_11eb_8990_a81e840b27ffrow6_col1" class="data row6 col1" >1576.040000</td>
#             </tr>
#             <tr>
#                         <th id="T_e7e2595c_a763_11eb_8990_a81e840b27fflevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_e7e2595c_a763_11eb_8990_a81e840b27ffrow7_col0" class="data row7 col0" >Eggs</td>
#                         <td id="T_e7e2595c_a763_11eb_8990_a81e840b27ffrow7_col1" class="data row7 col1" >1061.290000</td>
#             </tr>
#             <tr>
#                         <th id="T_e7e2595c_a763_11eb_8990_a81e840b27fflevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_e7e2595c_a763_11eb_8990_a81e840b27ffrow8_col0" class="data row8 col0" >Nuts & Peanut Butter</td>
#                         <td id="T_e7e2595c_a763_11eb_8990_a81e840b27ffrow8_col1" class="data row8 col1" >537.840000</td>
#             </tr>
#             <tr>
#                         <th id="T_e7e2595c_a763_11eb_8990_a81e840b27fflevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_e7e2595c_a763_11eb_8990_a81e840b27ffrow9_col0" class="data row9 col0" >Lamb & Goat</td>
#                         <td id="T_e7e2595c_a763_11eb_8990_a81e840b27ffrow9_col1" class="data row9 col1" >338.020000</td>
#             </tr>
#             <tr>
#                         <th id="T_e7e2595c_a763_11eb_8990_a81e840b27fflevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_e7e2595c_a763_11eb_8990_a81e840b27ffrow10_col0" class="data row10 col0" >Soybeans</td>
#                         <td id="T_e7e2595c_a763_11eb_8990_a81e840b27ffrow10_col1" class="data row10 col1" >111.870000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Below are some observations that can be noted from the table above:
# - The top three food products consumed are milk and cheese (40.67%), wheat and wheat products (23.13%), and rice (9.50%). Taken collectively, these three categories alone already total to close to three-fourths of the gross food consumption worldwide.
# - The three sources that are associated with the lowest CO<sub>2</sub> emissions are nuts and peanut butter, lamb and goat, and eggs. Taken collectively, they account for only 2.46% of the overall food consumption worldwide.
# - The consumption of milk and cheese is around three-fourths more than that of wheat and wheat products (which are second on the list). In turn, the consumption of wheat and wheat products is roughly two and a half times that of rice (which is third on the list).

# %% [markdown]
# ### 2. Carbon Dioxide Emission

# %% [markdown]
# We arrange the food categories based on the total carbon dioxide emission. As a preliminary visualization, we employ blue gradients to correspond to the amount of CO<sub>2</sub> emitted.

# %%
sorted_co2_food_data = food_data.sort_values(by = 'co2_emmission', ascending = False).reset_index(drop = True)
sorted_co2_food_data.drop(columns = ['consumption'], axis = 1, inplace = True)

sorted_co2_food_data.style.background_gradient(cmap = 'Reds')
# Out:
# <style  type="text/css" >
#     #T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow0_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow1_col1 {
#             background-color:  #fb7151;
#             color:  #000000;
#         }    #T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow2_col1 {
#             background-color:  #fcbda4;
#             color:  #000000;
#         }    #T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow3_col1 {
#             background-color:  #fed9c9;
#             color:  #000000;
#         }    #T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow4_col1 {
#             background-color:  #fee5d8;
#             color:  #000000;
#         }    #T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow5_col1 {
#             background-color:  #fee9df;
#             color:  #000000;
#         }    #T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow6_col1 {
#             background-color:  #ffebe2;
#             color:  #000000;
#         }    #T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow7_col1 {
#             background-color:  #ffefe8;
#             color:  #000000;
#         }    #T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow8_col1 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow9_col1 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow10_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_e7fab2c8_a763_11eb_ad06_a81e840b27ff" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >food_category</th>        <th class="col_heading level0 col1" >co2_emmission</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e7fab2c8_a763_11eb_ad06_a81e840b27fflevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow0_col0" class="data row0 col0" >Beef</td>
#                         <td id="T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow0_col1" class="data row0 col1" >48633.260000</td>
#             </tr>
#             <tr>
#                         <th id="T_e7fab2c8_a763_11eb_ad06_a81e840b27fflevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow1_col0" class="data row1 col0" >Milk & Cheese</td>
#                         <td id="T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow1_col1" class="data row1 col1" >23290.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_e7fab2c8_a763_11eb_ad06_a81e840b27fflevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow2_col0" class="data row2 col0" >Lamb & Goat</td>
#                         <td id="T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow2_col1" class="data row2 col1" >11837.380000</td>
#             </tr>
#             <tr>
#                         <th id="T_e7fab2c8_a763_11eb_ad06_a81e840b27fflevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow3_col0" class="data row3 col0" >Pork</td>
#                         <td id="T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow3_col1" class="data row3 col1" >7419.110000</td>
#             </tr>
#             <tr>
#                         <th id="T_e7fab2c8_a763_11eb_ad06_a81e840b27fflevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow4_col0" class="data row4 col0" >Rice</td>
#                         <td id="T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow4_col1" class="data row4 col1" >4886.910000</td>
#             </tr>
#             <tr>
#                         <th id="T_e7fab2c8_a763_11eb_ad06_a81e840b27fflevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow5_col0" class="data row5 col0" >Fish</td>
#                         <td id="T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow5_col1" class="data row5 col1" >3588.220000</td>
#             </tr>
#             <tr>
#                         <th id="T_e7fab2c8_a763_11eb_ad06_a81e840b27fflevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow6_col0" class="data row6 col0" >Poultry</td>
#                         <td id="T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow6_col1" class="data row6 col1" >2963.160000</td>
#             </tr>
#             <tr>
#                         <th id="T_e7fab2c8_a763_11eb_ad06_a81e840b27fflevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow7_col0" class="data row7 col0" >Wheat & Wheat Products</td>
#                         <td id="T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow7_col1" class="data row7 col1" >1773.780000</td>
#             </tr>
#             <tr>
#                         <th id="T_e7fab2c8_a763_11eb_ad06_a81e840b27fflevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow8_col0" class="data row8 col0" >Eggs</td>
#                         <td id="T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow8_col1" class="data row8 col1" >974.950000</td>
#             </tr>
#             <tr>
#                         <th id="T_e7fab2c8_a763_11eb_ad06_a81e840b27fflevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow9_col0" class="data row9 col0" >Nuts & Peanut Butter</td>
#                         <td id="T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow9_col1" class="data row9 col1" >951.990000</td>
#             </tr>
#             <tr>
#                         <th id="T_e7fab2c8_a763_11eb_ad06_a81e840b27fflevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow10_col0" class="data row10 col0" >Soybeans</td>
#                         <td id="T_e7fab2c8_a763_11eb_ad06_a81e840b27ffrow10_col1" class="data row10 col1" >50.350000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Below are some observations that can be noted from the table above:
# - The top three sources of CO<sub>2</sub> emissions are beef (45.72%), milk and cheese (21.90%), and lamb and goat products (11.13%). Taken collectively, these three categories alone already total to close to four-fifths of the gross food-related emission worldwide.
# - The three sources that are associated with the lowest CO<sub>2</sub> emissions are soybeans, nuts and peanut butter, and eggs. Taken collectively, they account for around 18% of the overall food-related emission worldwide.
# - Soybeans and nuts and peanut butter are also among the three least consumed products worldwide.
# - The emission due to beef products is over twice the emission due to milk and cheese products (which are second on the list). In turn, the emission due to cheese products is also over twice the emission due to lamb and goat (which are third on the list).

# %% [markdown]
# ### *Overall Bar Graph*

# %% [markdown]
# In order to give a more visual presentation of the data analyzed above, we construct a bar graph to show the total consumption vis-a-vis emission for each of the 11 food categories.

# %%
sorted_food_data = food_data.sort_values(by = 'co2_emmission', ascending = False).reset_index(drop = True)

# %%
fig = go.Figure(data = [
    go.Bar(x = sorted_food_data['food_category'],
          y = sorted_food_data['consumption'],
          name = 'Consumption'),
    
     go.Bar(x = sorted_food_data['food_category'],
          y = sorted_food_data['co2_emmission'],
          name = 'Carbon Dioxide Emission')
])

fig.update_layout(title = "Consumption and CO<sub>2</sub> Emission by Food Product",
                 xaxis_title = "Consumption (kg/person/year) and Emission (kg CO<sub>2</sub>/person/year)",
                 yaxis_title = "Country")

fig.show()
# Out:
# <div>                            <div id="da1232d1-3ec4-4470-bf33-0e512c9348b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da1232d1-3ec4-4470-bf33-0e512c9348b7")) {                    Plotly.newPlot(                        "da1232d1-3ec4-4470-bf33-0e512c9348b7",                        [{"name": "Consumption", "type": "bar", "x": ["Beef", "Milk & Cheese", "Lamb & Goat", "Pork", "Rice", "Fish", "Poultry", "Wheat & Wheat Products", "Eggs", "Nuts & Peanut Butter", "Soybeans"], "y": [1576.039999999999, 16350.71, 338.01999999999987, 2096.080000000001, 3818.7700000000004, 2247.320000000001, 2758.4999999999995, 9301.439999999999, 1061.2900000000002, 537.8399999999999, 111.87000000000002]}, {"name": "Carbon Dioxide Emission", "type": "bar", "x": ["Beef", "Milk & Cheese", "Lamb & Goat", "Pork", "Rice", "Fish", "Poultry", "Wheat & Wheat Products", "Eggs", "Nuts & Peanut Butter", "Soybeans"], "y": [48633.25999999999, 23289.999999999996, 11837.380000000001, 7419.109999999999, 4886.909999999999, 3588.2200000000003, 2963.16, 1773.7799999999993, 974.9499999999996, 951.9899999999998, 50.350000000000016]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333 ...

# %% [markdown]
# The graph above evinces the intense carbon dioxide emission that is associated with beef food products. Although its consumption is low (in fact, it is in the bottom half of the consumption hierarchy), its emission is immensely massive, accouning for 45.72% of total emission.
#
# On the other hand, although wheat and wheat products are consumed by a significant proportion of the global population (it is the second most-consumed food product), its emission is remarkably low, placing 8<sup>th</sup> in the emission hierarchy.
#
# This observation sparks interest as to whether there is a relationship (or, perhaps, a correlation) between the nature of the food product &mdash; beef is animal-derived whereas wheat is plant-based &mdash; and carbon dioxide emission, thus connecting this section to the next part of the data analysis, which focuses on statistical correlations.

# %% [markdown]
# <hr/>

# %% [markdown]
# ## C. Correlations

# %% [markdown]
# In the previous phases of the data analysis, our focus was on the independent treatment of the variables. Although certain patterns as to the interplay of these variables have been observed and hypothesized, they have not been subjected to any statistical verification. In this section, we are going to formally explore certain correlations of interest.

# %% [markdown]
# ### 1. Between Consumption & Carbon Dioxide Emission

# %% [markdown]
# First, we check if there is any correlation between consumption and carbon dioxide emission.

# %%
consumption_co2 = country_data[['country','TOTAL']]
consumption_co2 = consumption_co2.rename(columns = {"TOTAL": "Total Consumption"})

consumption_co2['Total CO2 Emission'] = co2_data['TOTAL']

print("-- Total Consumption and Carbon Dioxide Emission per Country --")
consumption_co2
# Out:
# -- Total Consumption and Carbon Dioxide Emission per Country --
# food_category    country  Total Consumption  Total CO2 Emission
# 0                Albania             532.73             1777.85
# 1                Algeria             364.51              707.88
# 2                 Angola             115.99              412.99
# 3              Argentina             429.41             2172.40
# 4                Armenia             407.11             1109.93
# ..                   ...                ...                 ...
# 125              Uruguay             433.60             1634.91
# 126            Venezuela             277.39             1104.10
# 127              Vietnam             268.74              641.51
# 128               Zambia              57.11              225.30
# 129             Zimbabwe              96.56              350.33
#
# [130 rows x 3 columns]

# %% [markdown]
# The scatterplot generated below seems to be indicative of a degree of correlation between consumption and carbon dioxide emission.

# %% [markdown]
# *Note that this is an interactive graph. Hovering allows for a more granular look at the data.*

# %%
fig = go.Figure(data = [
    go.Scatter(x = consumption_co2['Total Consumption'],
          y = consumption_co2['Total CO2 Emission'],
          mode = 'markers')
])

fig.update_layout(title = "Total Country-Level Consumption versus Total CO<sub>2</sub> Emission",
                 xaxis_title = "Total Consumption (kg/person/year)",
                 yaxis_title = "Total CO<sub>2</sub> Emission (kg CO<sub>2</sub>/person/year)")

fig.show()
# Out:
# <div>                            <div id="032b99dd-17df-4ed2-adbc-f7d779cec768" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("032b99dd-17df-4ed2-adbc-f7d779cec768")) {                    Plotly.newPlot(                        "032b99dd-17df-4ed2-adbc-f7d779cec768",                        [{"mode": "markers", "type": "scatter", "x": [532.73, 364.51, 115.99000000000001, 429.40999999999997, 407.11, 465.09000000000003, 469.14, 301.45, 236.6, 311.26, 321.5300000000001, 463.4599999999999, 232.76999999999998, 306.62, 204.25, 313.64, 188.85000000000002, 355.15999999999997, 348.42999999999995, 225.06000000000003, 97.09, 412.55, 335.06, 283.9, 235.02999999999994, 343.07, 433.87, 291.01000000000005, 303.65, 384.61, 499.06999999999994, 291.36, 303.48, 209.76, 464.9600000000001, 85.77000000000001, 252.52, 639.7900000000001, 479.17, 346.65999999999997, 180.56000000000003, 362.22, 461.09999999999997, 101.21000000000001, 493.63, 254.25, 133.29999999999998, 161.41000000000003, 185.76, 426.02000000000004, 352.99, 472.31000000000006, 227.7, 224.99, 292.26, 518.65, 457.75, 513.98, 273.02, 286.46000000000004, 291.41999999999996, 468.09999999999997, 162.56, 410.37999999999994, 348.54, 131.04, 555.01, 497.90000000000003, 321.47, 155.63, 51.0, 282.74, 476.32999999999987, 457.53999999999996, 358.12, 242.72, 296.01, 63.410000000000004, 275.1, 151.14999999999998, 208.55, 534.17, 321.24, 360.9200000000001, 196.95, 101.14000000000001, 94.22999999999999, 487.49, 363.66999999999996, 330.95, 260.53000000000003, 189.17, 215.19000000000003, 227.79, 411.42, 459.44, 117.33000000000001, 445.49, 408.73, 40.379999999999995, 291.82, 169.67, 326.71000000000004, 167.36999999999998, 350.05999999999995, 436.4099999999999, 212.41, 286.05999999999995, 407.96, 218.76999999999998, 150.3, 550.0, 514.9, 273.5, 98.83000000000001, 219.57999999999998, 74.32000000000001, 315.02, 370.92999999999995, 433.2099999999999, 80.58000000000001, 343.28, 397.71, 447.97, 491.15000000000003, 433.5999999999999, 277.39, 268.74, 57.11, 96.56], "y": [1777.85, 707.88, 412.9899999999999, 2172.3999999999996, 1109.9300000000003, 1938.6599999999999, 1211.16, 1192.9, 374.17999999999995, 889.11, 960.22, 1102.0899999999997, 433.08000000000004, 1483.28, 873.0300000000001, 628.18, 576.8399999999998, 1616.7299999999998, 560.16, 452.40999999999997, 283.61, 1437.1600000000003, 1099.5700000000002, 640.1899999999999, 781.53, 891.2700000000001, 996.1500000000001, 591.69, 741.37, 760.09, 1498.18, 883.88, 673.9200000000001, 434.04, 830.7199999999998, 241.92, 716.0899999999998, 1464.63, 1420.0500000000002, 1424.6899999999998, 293.66, 527.03, 1066.29, 217.87000000000003, 1497.29, 439.85, 314.9800000000001, 432.71, 434.08000000000004, 1494.2800000000002, 576.79, 1731.36, 282.62000000000006, 367.51, 445.2699999999999, 1459.67, 1405.71, 1206.3299999999997, 450.83000000000004, 644.04, 587.96, 1575.0799999999995, 530.8399999999999, 1345.4399999999998, 633.5799999999999, 203.38, 868.9, 1598.41, 600.75, 440.75, 207.94000000000003, 554.64, 903.4600000000002, 1147.9099999999999, 672.07, 797.1300000000001, 576.4199999999998, 141.39999999999998, 563.8000000000001, 362.10999999999996, 526.22, 1292.82, 918.6200000000001, 1750.95, 377.68999999999994, 542.89, 267.7900000000001, 1381.8899999999999, 1296.6999999999998, 669.0699999999999, 928.46, 876.6700000000002, 402.84000000000003, 455.28000000000014, 607.4000000000001, 1174.2799999999997, 262.54999999999995, 766.3000000000001, 1007.6599999999999, 181.63, 692.86, 469.42999999999995, 723.3399999999999, 300.41, 560.34, 1111.56, 892.4100000000002, 822.0500000000001, 988.4699999999999, 294.46000000000004, 678.94, 1527.03, 1356.7499999999998, 559.5500000000001, 343.02, 378.0, 188.09, 610.4100000000001, 618.8900000000001, 897.0099999999999, 304.72000 ...

# %% [markdown]
# In order to give a numerical score to the strength of this correlation, the **Pearson correlation coefficient** (also refered to as **Pearson's *r***) is employed.

# %%
x = np.array(consumption_co2['Total Consumption'])
y = np.array(consumption_co2['Total CO2 Emission'])

scipy.stats.pearsonr(x, y)
# Out:
# (0.8003280560404025, 3.200073281545265e-30)

# %% [markdown]
# Since the correlation coefficient (the first value in the tuple returned by the <code>scipy</code> function) is 0.80, there exists a **high positive correlation between consumption and carbon dioxide emission**.

# %% [markdown]
# ### 2. Between Food Source & Carbon Dioxide Emission

# %% [markdown]
# Next, we check if there is any correlation between the predominant food source (either animal or plant) of a country and carbon dioxide emission.
#
# The creator of the dataset, nu3 (2018), suggested taking the difference between the total animal-based food product-related emission and the total plant-based food product-related emission:
#
# <blockquote> A low value means that a larger proportion of the population feeds on plant products which have a better carbon emission footprint. A negative value means that the majority of the population consumes more non-animal products than animal products and the carbon emissions caused by these products are higher in the country concerned than the total emissions caused by animal products. </blockquote>

# %%
animal_plant = animal_co2_data[['country', 'TOTAL']]
animal_plant = animal_plant.rename(columns = {"TOTAL": "Animal-Based Food Product Emission"})

animal_plant['Plant-Based Food Product Emission'] = plant_co2_data['TOTAL']
animal_plant['Total'] = animal_plant['Animal-Based Food Product Emission'] + animal_plant['Plant-Based Food Product Emission']
animal_plant['Difference'] = animal_plant['Animal-Based Food Product Emission'] - animal_plant['Plant-Based Food Product Emission']

animal_plant
# Out:
# food_category    country  Animal-Based Food Product Emission  \
# 0                Albania                             1733.73
# 1                Algeria                              665.04
# 2                 Angola                              390.60
# 3              Argentina                             2140.65
# 4                Armenia                             1076.44
# ..                   ...                                 ...
# 125              Uruguay                             1597.66
# 126            Venezuela                             1064.17
# 127              Vietnam                              440.81
# 128               Zambia                              206.88
# 129             Zimbabwe                              327.28
#
# food_category  Plant-Based Food Product Emission    Total  Difference
# 0                                          44.12  1777.85     1689.61
# 1                                          42.84   707.88      622.20
# 2                                          22.39   412.99      368.21
# 3                                          31.75  2172.40     2108.90
# 4                                          33.49  1109.93     1042.95
# ..                                           ...      ...         ...
# 125                                        37.25  1634.91     1560.41
# 126                                        39.93  1104.10     1024.24
# 127                                       200.70   641.51      240.11
# 128                                        18.42   225.30      188.46
# 129                                        23.05   350.33      304.23
#
# [130 rows x 5 columns]

# %% [markdown]
# We arrange the entries based on this difference. As a preliminary visualization, we employ red gradients to correspond to the intensity of the difference.

# %%
sorted_animal_plant = animal_plant.sort_values(by = 'Difference', ascending = False).reset_index(drop = True)
sorted_animal_plant.style.background_gradient(cmap = 'Reds')
# Out:
# <style  type="text/css" >
#     #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow0_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow0_col2 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow0_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow0_col4 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow1_col1 {
#             background-color:  #a10e15;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow1_col2 {
#             background-color:  #fed9c9;
#             color:  #000000;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow1_col3 {
#             background-color:  #9f0e14;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow1_col4 {
#             background-color:  #a10e15;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow2_col1 {
#             background-color:  #bb141a;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow2_col2 {
#             background-color:  #fed8c7;
#             color:  #000000;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow2_col3 {
#             background-color:  #b91419;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow2_col4 {
#             background-color:  #b91419;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow3_col1 {
#             background-color:  #be151a;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow3_col2 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow3_col3 {
#             background-color:  #c1161b;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow3_col4 {
#             background-color:  #bb141a;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow4_col1 {
#             background-color:  #be151a;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow4_col2 {
#             background-color:  #fedccd;
#             color:  #000000;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow4_col3 {
#             background-color:  #be151a;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow4_col4 {
#             background-color:  #bc141a;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow5_col1 {
#             background-color:  #c3161b;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow5_col2 {
#             background-color:  #fee0d2;
#             color:  #000000;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow5_col3 {
#             background-color:  #c3161b;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow5_col4 {
#             background-color:  #bf151b;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow6_col1 {
#             background-color:  #cf1c1f;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow6_col2 {
#             background-color:  #fee1d3;
#             color:  #000000;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow6_col3 {
#             background-color:  #cf1c1f;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow6_col4 {
#             background-color:  #cb181d;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow7_col1 {
#             background-color:  #d21f20;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow7_col2 {
#             background-color:  #fee9df;
#             color:  #000000;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow7_col3 {
#             background-color:  #d42121;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow7_col4 {
#             background-color:  #ce1a1e;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow8_col1 {
#             background-color:  #d32020;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow8_col2 {
#             background-color:  #fdcab5;
#             color:  #000000;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow8_col3 {
#             background-color:  #d21f20;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow8_col4 {
#             background-color:  #d21f20;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow9_col1 {
#             background-color:  #d72322;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow9_col2 {
#             background-color:  #fee2d5;
#             color:  #000000;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow9_col3 {
#             background-color:  #d82422;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow9_col4 {
#             background-color:  #d32020;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow10_col1 {
#             background-color:  #dd2a25;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow10_col2 {
#             background-color:  #fee3d7;
#             color:  #000000;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow10_col3 {
#             background-color:  #de2b25;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow10_col4 {
#             background-color:  #d92523;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow11_col1 {
#             background-color:  #e22e27;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow11_col2 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow11_col3 {
#             background-color:  #e43027;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow11_col4 {
#             background-color:  #dc2924;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow12_col1 {
#             background-color:  #e22e27;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow12_col2 {
#             background-color:  #fee2d5;
#             color:  #000000;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow12_col3 {
#             background-color:  #e22e27;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow12_col4 {
#             background-color:  #dc2924;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow13_col1 {
#             background-color:  #e53228;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow13_col2 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow13_col3 {
#             background-color:  #e83429;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow13_col4 {
#             background-color:  #de2b25;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow14_col1 {
#             background-color:  #e63328;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow14_col2 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow14_col3 {
#             background-color:  #e83429;
#             color:  #f1f1f1;
#         }    #T_e908e4f0_a763_11eb_880f_a81e840b27ffrow14_col4 {
#             background-color:  #e12d26;

# %% [markdown]
# Scrolling through the table seems to evince a correlation between the total emission and the said difference metric. We confirm this graphically through the scatterplot generated below.

# %% [markdown]
# *Note that this is an interactive plot. Hovering allows for a more granular look at the data.*

# %%
fig = go.Figure(data = [
    go.Scatter(x = animal_plant['Difference'],
          y = animal_plant['Total'],
          mode = 'markers')
])

fig.update_layout(title = "Total Country-Level Emission versus Animal-to-Plant-Based Emission Difference",
                 xaxis_title = "Total Country-Level Emission (kg CO<sub>2</sub>/person/year)",
                 yaxis_title = "Animal-to-Plant-Based Emission Difference (kg CO<sub>2</sub>/person/year)")

fig.show()
# Out:
# <div>                            <div id="5e39ba11-faaf-46e1-85fb-0087e938b0f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e39ba11-faaf-46e1-85fb-0087e938b0f9")) {                    Plotly.newPlot(                        "5e39ba11-faaf-46e1-85fb-0087e938b0f9",                        [{"mode": "markers", "type": "scatter", "x": [1689.6099999999997, 622.2, 368.2099999999999, 2108.9, 1042.9500000000003, 1852.46, 1141.0, 1101.98, -75.08000000000004, 809.1500000000001, 916.8600000000001, 1011.3899999999998, 318.26, 1428.14, 752.4700000000001, 579.26, 539.3599999999999, 1508.6299999999997, 500.15999999999997, 35.849999999999966, 180.49, 1343.18, 1029.0700000000002, 390.0099999999999, 696.1700000000001, 753.0699999999999, 934.99, 391.05, 680.65, 703.0100000000001, 1427.0600000000002, 750.12, 509.1200000000001, 391.7, 774.8599999999999, 219.56, 562.3299999999999, 1409.81, 1347.0900000000001, 1298.4299999999998, 102.25999999999998, 449.19, 996.9499999999999, 110.69000000000003, 1395.79, 392.03000000000003, 279.44000000000005, 162.41, 380.2800000000001, 1311.34, 527.0899999999999, 1679.74, 74.50000000000001, -5.14999999999992, 267.09, 1396.0700000000004, 1293.01, 1108.7899999999997, 357.40999999999997, 457.92, 472.84, 1502.9199999999998, 478.52, 1177.78, 586.98, -48.5, 807.1, 1544.97, 532.3699999999999, 173.65, 171.74, 316.92, 687.7400000000001, 1062.03, 503.4700000000001, 760.37, 493.6199999999999, 66.64, 205.26, 329.57, 273.8400000000001, 1230.36, 831.74, 1668.6699999999998, 247.68999999999994, 482.7699999999999, 160.71000000000004, 1314.89, 1121.4, 591.43, 736.7, 846.4300000000002, 252.5, 133.38, 555.5, 1086.44, 194.10999999999999, 701.86, 939.86, 151.25, 555.08, 255.90999999999997, 668.1199999999999, 12.98999999999998, 492.7, 1042.64, 820.0900000000001, 559.85, 905.01, -4.339999999999975, 587.34, 1459.2299999999998, 1283.1699999999998, 375.45, 262.1, 73.35999999999999, 103.95, 520.67, 516.69, 774.9499999999999, 275.64000000000004, 608.4499999999999, 633.1200000000001, 1172.81, 1642.72, 1560.4099999999999, 1024.24, 240.10999999999999, 188.4600000000001, 304.22999999999996], "y": [1777.85, 707.8800000000001, 412.9899999999999, 2172.4, 1109.9300000000003, 1938.6599999999999, 1211.1599999999999, 1192.9, 374.18, 889.1100000000001, 960.22, 1102.0899999999997, 433.08000000000004, 1483.28, 873.0300000000001, 628.1800000000001, 576.8399999999999, 1616.7299999999996, 560.16, 452.40999999999997, 283.61, 1437.16, 1099.5700000000002, 640.1899999999999, 781.53, 891.27, 996.1500000000001, 591.69, 741.37, 760.09, 1498.18, 883.88, 673.9200000000001, 434.04, 830.7199999999998, 241.92000000000002, 716.0899999999999, 1464.63, 1420.0500000000002, 1424.69, 293.65999999999997, 527.03, 1066.29, 217.87000000000003, 1497.29, 439.8500000000001, 314.98, 432.71000000000004, 434.08000000000004, 1494.28, 576.79, 1731.36, 282.62000000000006, 367.51, 445.2699999999999, 1459.6700000000003, 1405.7099999999998, 1206.3299999999997, 450.83000000000004, 644.04, 587.96, 1575.0799999999997, 530.8399999999999, 1345.4399999999998, 633.5799999999999, 203.38, 868.9, 1598.41, 600.75, 440.75, 207.94, 554.64, 903.4600000000002, 1147.91, 672.07, 797.13, 576.4199999999998, 141.39999999999998, 563.8, 362.10999999999996, 526.2200000000001, 1292.82, 918.6200000000001, 1750.95, 377.68999999999994, 542.8899999999999, 267.79, 1381.89, 1296.6999999999998, 669.07, 928.46, 876.6700000000002, 402.84000000000003, 455.2800000000001, 607.4000000000001, 1174.2800000000002, 262.55, 766.3000000000001, 1007.66, 181.63, 692.86, 469.42999999999995, 723.3399999999999, 300.40999999999997, 560.34, 1111.5600000000002, 892.4100000000001, 822.0500000000001, 988.47, 294.46000000000004, 678.9399999999999, 1527.03, 1356.7499999999998, 559.55, 343.02, 378.0, 188.090000 ...

# %% [markdown]
# Visual inspection is sufficient to notice the markedly linear correlation between the variables being observed. Nevertheless, we still have to employ **Pearson correlation coefficient** (also known as **Pearson's *r***) to assign a numerical score to this correlation.

# %%
x = np.array(animal_plant['Difference'])
y = np.array(animal_plant['Total'])

scipy.stats.pearsonr(x, y)
# Out:
# (0.9840473105876909, 7.569400961764421e-98)

# %% [markdown]
# Since the correlation coefficient (the first value in the tuple returned by the <code>scipy</code> function) is 0.98, there exists a **very high positive correlation between the predominant food source of a country and its carbon dioxide emission**.

# %% [markdown]
# # References

# %% [markdown]
# - European Union. (2021). *Animal products*. https://ec.europa.eu/info/food-farming-fisheries/animals-and-animal-products/animal-products/
# - Mottaleb, K., Rahut, D.N., Kruseman, G., & Erenstein, O. (2017). Wheat production and consumption dynamics in an Asian rice economy: The Bangladesh case. *European Journal of Development Research, 30*(1), 1-24. doi:10.1057/s41287-017-0096-1
# - nu3. (2018). *Food carbon footprint index 2018*. https://www.nu3.de/blogs/nutrition/food-carbon-footprint-index-2018
# - Quinton, A. (2019, June 27). *Cows and climate change*. University of California, Davis. https://www.ucdavis.edu/food/news/making-cattle-more-sustainable
# - Stylianou, N., Guibourg, C., & Briggs, H. (2019, August 9). *Climate change calculator: What's your diet's carbon footprint?* https://www.bbc.com/news/science-environment-46459714
# - World Health Organization. (n.d.). *Congo*. https://www.who.int/countries/cog/
